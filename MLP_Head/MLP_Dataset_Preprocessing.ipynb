# %%
# Install gdown if not already installed
# !pip install -q gdown

# Download the file from Google Drive
file_id = "12IUNRSUmQx6YdXa_BbTfpztPoT2GfVNK"
# !gdown --id {file_id} -O MLP_dataset.zip

# Create folder to store extracted files
# !mkdir -p MLP_dataset

# Unzip the contents into MLP_dataset
# !unzip -q MLP_dataset.zip -d MLP_dataset

# Verify contents
# !ls MLP_dataset
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=12IUNRSUmQx6YdXa_BbTfpztPoT2GfVNK
# From (redirected): https://drive.google.com/uc?id=12IUNRSUmQx6YdXa_BbTfpztPoT2GfVNK&confirm=t&uuid=7d595eaa-9ad2-4d34-8e62-b81c8b62da81
# To: /content/MLP_dataset.zip
# 100% 203M/203M [00:02<00:00, 90.2MB/s]
# Positive_FGNET	Positive_Morph

# %% [markdown]
# # count number of samples in MLP_dataset

# %%
import os

base_dir = "MLP_dataset"
subfolders = ["Positive_FGNET", "Positive_Morph"]

for folder in subfolders:
    folder_path = os.path.join(base_dir, folder)
    # Count files with common image extensions
    count = len([f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
    print(f"{folder}: {count} images")
# Out:
# Positive_FGNET: 0 images
# Positive_Morph: 0 images

# %%
import os

# List everything inside MLP_dataset
base_dir = "/content/MLP_dataset"
for root, dirs, files in os.walk(base_dir):
    print("Current folder:", root)
    print("Subfolders:", dirs)
    print("Files:", files[:10])  # show first 10 files
    print("---")
# Out:
# Current folder: /content/MLP_dataset
# Subfolders: ['Positive_Morph', '.ipynb_checkpoints', 'Positive_FGNET']
# Files: []
# ---
# Current folder: /content/MLP_dataset/Positive_Morph
# Subfolders: ['063049_42-53', '07609_17-43', '129358_34-44', '13884_27-42', '41803_17-27', '132878_30-35', '110160_29-39', '285512_19-24', '063148_36-42', '5850_17-36', '265688_39-48', '096464_35-52', '37801_24-47', '130092_27-33', '105342_39-46', '122763_24-33', '098246_45-50', '320016_16-27', '2032_44-50', '080905_38-48', '063238_48-62', '078329_37-42', '054477_43-55', '096151_38-51', '02335_35-45', '053541_44-50', '108590_37-44', '099857_36-43', '092228_40-51', '127267_37-44', '313385_29-40', '08229_18-38', '041002_50-55', '12740_27-35', '104470_33-38', '03619_20-40', '2218_17-42', '0771_16-48', '105685_32-37', '18082_18-29', '115749_32-43', '28227_17-40', '103847_40-45', '150629_42-53', '196217_39-45', '328228_28-58', '76587_37-47', '076181_34-40', '01239_27-49', '20143_20-35', '8230_24-34', '02701_43-48', '094281_37-42', '117112_34-42', '121526_31-36', '132102_34-39', '054846_44-53', '040685_39-52', '113621_36-41', '070967_39-49', '7541_21-40', '097950_38-47', '5450_28-36', '120381_33-38', '103343_32-37', '069975_40-54', '237679_43-54', '260710_41-52', '048628_39-49', '118881_38-43', '233131_41-48', '093662_54-60', '079419_40-52', '94852_19-29', '68633_47-53', '127870_33-38', '94261_28-39', '191920_38-49', '6227_38-44', '117757_39-51', '130630_43-48', '048318_48-53', '061923_35-42', '094590_48-59', '180361_38-45', '14095_21-27', '063693_39-52', '092926_38-50', '115740_37-48', '085671_40-51', '136953_30-35', '064584_42-51', '046271_44-49', '116805
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_02_34
# Subfolders: []
# Files: ['011A34.JPG', '011A02.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_07_30
# Subfolders: []
# Files: ['011A30.JPG', '011A07.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_14_30
# Subfolders: []
# Files: ['011A30.JPG', '011A14.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_17_42
# Subfolders: []
# Files: ['011A42.JPG', '011A17.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_27_42
# Subfolders: []
# Files: ['011A42.JPG', '011A27.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_02_30
# Subfolders: []
# Files: ['011A30.JPG', '011A02.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_11_34
# Subfolders: []
# Files: ['011A11.JPG', '011A34.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_20_34
# Subfolders: []
# Files: ['011A34.JPG', '011A20.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_05_30
# Subfolders: []
# Files: ['011A30.JPG', '011A05.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_17_30
# Subfolders: []
# Files: ['011A30.JPG', '011A17.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_13_40
# Subfolders: []
# Files: ['011A13.JPG', '011A40.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_05_40
# Subfolders: []
# Files: ['011A40.JPG', '011A05.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_02_15
# Subfolders: []
# Files: ['011A15.JPG', '011A02.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_07_20
# Subfolders: []
# Files: ['011A07.JPG', '011A20.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_02_17
# Subfolders: []
# Files: ['011A02.JPG', '011A17.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_27_40
# Subfolders: []
# Files: ['011A40.JPG', '011A27.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_14_42
# Subfolders: []
# Files: ['011A42.JPG', '011A14.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_07_27
# Subfolders: []
# Files: ['011A27.JPG', '011A07.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_02_40
# Subfolders: []
# Files: ['011A40.JPG', '011A02.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_14_27
# Subfolders: []
# Files: ['011A27.JPG', '011A14.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_02_42
# Subfolders: []
# Files: ['011A42.JPG', '011A02.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_20_40
# Subfolders: []
# Files: ['011A40.JPG', '011A20.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_30_42
# Subfolders: []
# Files: ['011A30.JPG', '011A42.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_13_27
# Subfolders: []
# Files: ['011A13.JPG', '011A27.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_13_30
# Subfolders: []
# Files: ['011A13.JPG', '011A30.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_20_42
# Subfolders: []
# Files: ['011A42.JPG', '011A20.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_07_42
# Subfolders: []
# Files: ['011A42.JPG', '011A07.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_17_34
# Subfolders: []
# Files: ['011A34.JPG', '011A17.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_13_34
# Subfolders: []
# Files: ['011A13.JPG', '011A34.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_02_13
# Subfolders: []
# Files: ['011A13.JPG', '011A02.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_15_34
# Subfolders: []
# Files: ['011A34.JPG', '011A15.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_14_34
# Subfolders: []
# Files: ['011A34.JPG', '011A14.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_14_40
# Subfolders: []
# Files: ['011A40.JPG', '011A14.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_15_27
# Subfolders: []
# Files: ['011A15.JPG', '011A27.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_11_27
# Subfolders: []
# Files: ['011A11.JPG', '011A27.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_05_34
# Subfolders: []
# Files: ['011A05.JPG', '011A34.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_15_42
# Subfolders: []
# Files: ['011A42.JPG', '011A15.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_07_34
# Subfolders: []
# Files: ['011A34.JPG', '011A07.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_05_17
# Subfolders: []
# Files: ['011A05.JPG', '011A17.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_11_30
# Subfolders: []
# Files: ['011A30.JPG', '011A11.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_05_42
# Subfolders: []
# Files: ['011A05.JPG', '011A42.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_17_40
# Subfolders: []
# Files: ['011A40.JPG', '011A17.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_05_20
# Subfolders: []
# Files: ['011A05.JPG', '011A20.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_15_40
# Subfolders: []
# Files: ['011A40.JPG', '011A15.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_02_14
# Subfolders: []
# Files: ['011A02.JPG', '011A14.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_11_42
# Subfolders: []
# Files: ['011A11.JPG', '011A42.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_15_30
# Subfolders: []
# Files: ['011A30.JPG', '011A15.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_07_40
# Subfolders: []
# Files: ['011A40.JPG', '011A07.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_13_42
# Subfolders: []
# Files: ['011A13.JPG', '011A42.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_05_27
# Subfolders: []
# Files: ['011A05.JPG', '011A27.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_02_27
# Subfolders: []
# Files: ['011A27.JPG', '011A02.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_02_20
# Subfolders: []
# Files: ['011A02.JPG', '011A20.JPG']
# ---
# Current folder: /content/MLP_dataset/Positive_FGNET/person011/person011_11_40
# Subfolders: []
# Files: ['011A40.JPG', '011A11.JPG']
# ---

# %%
import os

def count_images(folder):
    image_count = 0
    for root, dirs, files in os.walk(folder):
        image_count += len([f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
    return image_count

base_dir = "/content/MLP_dataset"
folders = ["Positive_Morph", "Positive_FGNET"]

for f in folders:
    path = os.path.join(base_dir, f)
    total = count_images(path)
    print(f"{f}: {total} images")
# Out:
# Positive_Morph: 1410 images
# Positive_FGNET: 4474 images

# %% [markdown]
# # Preprocess image pairs in Positive_FGNET

# %%
# !pip install facenet_pytorch
# Out:
# Collecting facenet_pytorch
#   Downloading facenet_pytorch-2.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting numpy<2.0.0,>=1.24.0 (from facenet_pytorch)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.1 MB/s eta 0:00:00
# Collecting Pillow<10.3.0,>=10.2.0 (from facenet_pytorch)
#   Downloading pillow-10.2.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from facenet_pytorch) (2.32.4)
# Collecting torch<2.3.0,>=2.2.0 (from facenet_pytorch)
#   Downloading torch-2.2.2-cp312-cp312-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting torchvision<0.18.0,>=0.17.0 (from facenet_pytorch)
#   Downloading torchvision-0.17.2-cp312-cp312-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from facenet_pytorch) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->facenet_pytorch) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->facenet_pytorch) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->facenet_pytorch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->facenet_pytorch) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<2.3.0,>=2.2.0->facenet_pytorch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.3.0,>=2.2.0->facenet_pytorch) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch<2.3.0,>=2.2.0->facenet_pytorch) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<2.3.0,>=2.2.0->facenet_pytorch) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.3.0,>=2.2.0->facenet_pytorch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<2.3.0,>=2.2.0->facenet_pytorch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch<2.3.0,>=2.2.0->facenet_pytorch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch<2.3.0,>=2.2.0->facenet_pytorch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch<2.3.0,>=2.2.0->facenet_pytorch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch<2.3.0,>=2.2.0->facenet_pytorch)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch<2.3.0,>=2.2.0->facenet_pytorch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch<2.3.0,>=2.2.0->facenet_pytorch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch<2.3.0,>=2.2.0->facenet_pytorch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch<2.3.0,>=2.2.0->facenet_pytorch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch<2.3.0,>=2.2.0->facenet_pytorch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch<2.3.0,>=2.2.0->facenet_pytorch)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch<2.3.0,>=2.2.0->facenet_pytorch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.3.0,>=2.2.0->facenet_pytorch) (12.6.85)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.3.0,>=2.2.0->facenet_pytorch) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch<2.3.0,>=2.2.0->facenet_pytorch) (1.3.0)
# Downloading facenet_pytorch-2.6.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 30.1 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 107.6 MB/s eta 0:00:00
# Downloading pillow-10.2.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 113.6 MB/s eta 0:00:00
# Downloading torch-2.2.2-cp312-cp312-manylinux1_x86_64.whl (755.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 117.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 94.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 43.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.7 MB/s eta 0:00:00
# Downloading torchvision-0.17.2-cp312-cp312-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 94.2 MB/s eta 0:00:00
# Installing collected packages: Pillow, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, torchvision, facenet_pytorch
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: torch
#     Found existing installation: torch 2.9.0+cu126
#     Uninstalling torch-2.9.0+cu126:
#       Successfully uninstalled torch-2.9.0+cu126
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.24.0+cu126
#     Uninstalling torchvision-0.24.0+cu126:
#       Successfully uninstalled torchvision-0.24.0+cu126
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.9.0+cu126 requires torch==2.9.0, but you have torch 2.2.2 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed Pillow-10.2.0 facenet_pytorch-2.6.0 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvtx-cu12-12.1.105 torch-2.2.2 torchvision-0.17.2

# %%
import gdown
import tensorflow as tf
from facenet_pytorch import MTCNN, InceptionResnetV1
from PIL import Image
import numpy as np
import cv2
from matplotlib import pyplot as plt
from scipy.spatial.distance import cosine
import torch

# -----------------------------
# 1. Load Models
# -----------------------------
# Age prediction model
file_id = "1xyGYBYRQwjBpPreZmvv_enQ3Z92wHNSx"
download_url = f"https://drive.google.com/uc?id={file_id}"
output_path = "resnet50_age_model.keras"
gdown.download(download_url, output_path, quiet=False)
age_model = tf.keras.models.load_model(output_path)

# Face detection
mtcnn = MTCNN()

# Face matching model
facenet = InceptionResnetV1(pretrained='vggface2').eval()

print("✓ All models loaded!")

# -----------------------------
# 2. Helper Functions
# -----------------------------
def align_face(img_cv, landmark, output_size=(224, 224)):
    """Align face based on eye landmarks"""
    left_eye, right_eye, nose = landmark[0], landmark[1], landmark[2]

    eyes_center = ((left_eye[0] + right_eye[0]) / 2,
                   (left_eye[1] + right_eye[1]) / 2)

    dy, dx = right_eye[1] - left_eye[1], right_eye[0] - left_eye[0]
    angle = np.degrees(np.arctan2(dy, dx))

    desired_eye_distance = output_size[0] * 0.35
    dist = np.sqrt(dx**2 + dy**2)
    scale = desired_eye_distance / dist

    M = cv2.getRotationMatrix2D(eyes_center, angle, scale)
    M[0, 2] += (output_size[0] * 0.5 - eyes_center[0])
    M[1, 2] += (output_size[1] * 0.4 - eyes_center[1])

    aligned_face = cv2.warpAffine(img_cv, M, output_size, flags=cv2.INTER_CUBIC)
    return aligned_face

def preprocess_for_age(face_img):
    """Preprocess for age model (ResNet50)"""
    from tensorflow.keras.applications.resnet50 import preprocess_input
    x = cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return x

def preprocess_for_facenet(face_img):
    """Preprocess for FaceNet (160x160, normalized)"""
    face_resized = cv2.resize(face_img, (160, 160))
    face_rgb = cv2.cvtColor(face_resized, cv2.COLOR_BGR2RGB)
    face_normalized = (face_rgb - 127.5) / 128.0
    face_tensor = torch.FloatTensor(face_normalized).permute(2, 0, 1).unsqueeze(0)
    return face_tensor

# -----------------------------
# 3. Main Function
# -----------------------------
def match_faces(img_path1, img_path2, threshold=0.6):
    """
    Match two face images

    Args:
        img_path1, img_path2: Paths to images
        threshold: Similarity threshold (default 0.6)

    Returns:
        Dictionary with results
    """
    results = {}

    # Process Image 1
    img1 = Image.open(img_path1).convert('RGB')
    img1_cv = cv2.cvtColor(np.array(img1), cv2.COLOR_RGB2BGR)
    boxes1, probs1, landmarks1 = mtcnn.detect(img1, landmarks=True)

    if boxes1 is None:
        print(f"No face detected in {img_path1}")
        return None

    aligned_face1 = align_face(img1_cv, landmarks1[0], output_size=(224, 224))

    # Age prediction for Image 1
    age_input1 = preprocess_for_age(aligned_face1)
    age1 = age_model.predict(age_input1, verbose=0)[0][0]

    # Face embedding for Image 1
    face_tensor1 = preprocess_for_facenet(aligned_face1)
    with torch.no_grad():
        embedding1 = facenet(face_tensor1).numpy().flatten()

    # Process Image 2
    img2 = Image.open(img_path2).convert('RGB')
    img2_cv = cv2.cvtColor(np.array(img2), cv2.COLOR_RGB2BGR)
    boxes2, probs2, landmarks2 = mtcnn.detect(img2, landmarks=True)

    if boxes2 is None:
        print(f"No face detected in {img_path2}")
        return None

    aligned_face2 = align_face(img2_cv, landmarks2[0], output_size=(224, 224))

    # Age prediction for Image 2
    age_input2 = preprocess_for_age(aligned_face2)
    age2 = age_model.predict(age_input2, verbose=0)[0][0]

    # Face embedding for Image 2
    face_tensor2 = preprocess_for_facenet(aligned_face2)
    with torch.no_grad():
        embedding2 = facenet(face_tensor2).numpy().flatten()

    # Compute similarity
    similarity = 1 - cosine(embedding1, embedding2)
    is_match = similarity >= threshold

    # Store results
    results = {
        'age1': float(age1),
        'age2': float(age2),
        'age_difference': abs(float(age1 - age2)),
        'similarity': float(similarity),
        'is_match': is_match,
        'threshold': threshold,
        'face1': aligned_face1,
        'face2': aligned_face2
    }

    return results
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1xyGYBYRQwjBpPreZmvv_enQ3Z92wHNSx
# From (redirected): https://drive.google.com/uc?id=1xyGYBYRQwjBpPreZmvv_enQ3Z92wHNSx&confirm=t&uuid=9dfe924d-ab89-4395-a89a-774597f1ac50
# To: /content/resnet50_age_model.keras
# 100%|██████████| 185M/185M [00:01<00:00, 124MB/s]
#   0%|          | 0.00/107M [00:00<?, ?B/s]
# ✓ All models loaded!

# %%
import os
import csv
import gdown
import tensorflow as tf
from facenet_pytorch import MTCNN, InceptionResnetV1
from PIL import Image
import numpy as np
import cv2
import torch
from pathlib import Path

# -----------------------------
# 1. Load Models
# -----------------------------
print("Loading models...")
# Age prediction model
output_path = "resnet50_age_model.keras"
if not os.path.exists(output_path):
    print("Downloading age model...")
    file_id = "1xyGYBYRQwjBpPreZmvv_enQ3Z92wHNSx"
    download_url = f"https://drive.google.com/uc?id={file_id}"
    gdown.download(download_url, output_path, quiet=False)
else:
    print("Age model already exists, skipping download...")

age_model = tf.keras.models.load_model(output_path)

# Face detection
mtcnn = MTCNN()

# Face matching model
facenet = InceptionResnetV1(pretrained='vggface2').eval()

print("✓ All models loaded!")

# -----------------------------
# 2. Helper Functions
# -----------------------------
def align_face(img_cv, landmark, output_size=(224, 224)):
    """Align face based on eye landmarks"""
    left_eye, right_eye, nose = landmark[0], landmark[1], landmark[2]

    eyes_center = ((left_eye[0] + right_eye[0]) / 2,
                   (left_eye[1] + right_eye[1]) / 2)

    dy, dx = right_eye[1] - left_eye[1], right_eye[0] - left_eye[0]
    angle = np.degrees(np.arctan2(dy, dx))

    desired_eye_distance = output_size[0] * 0.35
    dist = np.sqrt(dx**2 + dy**2)
    scale = desired_eye_distance / dist

    M = cv2.getRotationMatrix2D(eyes_center, angle, scale)
    M[0, 2] += (output_size[0] * 0.5 - eyes_center[0])
    M[1, 2] += (output_size[1] * 0.4 - eyes_center[1])

    aligned_face = cv2.warpAffine(img_cv, M, output_size, flags=cv2.INTER_CUBIC)
    return aligned_face

def preprocess_for_age(face_img):
    """Preprocess for age model (ResNet50)"""
    from tensorflow.keras.applications.resnet50 import preprocess_input
    # Ensure the image is in the correct format (BGR -> RGB)
    x = cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)
    # Convert to float32
    x = x.astype(np.float32)
    # Expand dimensions to add batch dimension
    x = np.expand_dims(x, axis=0)
    # Apply ResNet50 preprocessing
    x = preprocess_input(x)
    return x

def preprocess_for_facenet(face_img):
    """Preprocess for FaceNet (160x160, normalized)"""
    face_resized = cv2.resize(face_img, (160, 160))
    face_rgb = cv2.cvtColor(face_resized, cv2.COLOR_BGR2RGB)
    face_normalized = (face_rgb - 127.5) / 128.0
    face_tensor = torch.FloatTensor(face_normalized).permute(2, 0, 1).unsqueeze(0)
    return face_tensor

def process_image(img_path):
    """
    Process a single image: detect face, align, predict age, get embedding
    Returns: (age, embedding) or (None, None) if face not detected
    """
    try:
        # Load image
        img = Image.open(img_path).convert('RGB')
        img_cv = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)

        # Detect face
        boxes, probs, landmarks = mtcnn.detect(img, landmarks=True)

        if boxes is None or len(boxes) == 0:
            print(f"  ⚠ No face detected in {img_path}")
            return None, None

        # Align face
        aligned_face = align_face(img_cv, landmarks[0], output_size=(224, 224))

        # Ensure aligned face is valid
        if aligned_face is None or aligned_face.shape != (224, 224, 3):
            print(f"  ⚠ Invalid aligned face shape in {img_path}")
            return None, None

        # Age prediction
        age_input = preprocess_for_age(aligned_face)

        # Ensure proper shape for age model
        if age_input.shape != (1, 224, 224, 3):
            print(f"  ⚠ Invalid age input shape: {age_input.shape}")
            return None, None

        age = age_model.predict(age_input, verbose=0)[0][0]

        # Face embedding
        face_tensor = preprocess_for_facenet(aligned_face)
        with torch.no_grad():
            embedding = facenet(face_tensor).numpy().flatten()

        return float(age), embedding.tolist()

    except Exception as e:
        print(f"  ✗ Error processing {img_path}: {str(e)}")
        import traceback
        traceback.print_exc()
        return None, None

def process_dataset(dataset_root, output_csv):
    """
    Process all image pairs in the dataset

    Args:
        dataset_root: Path to Positive_FGNET folder
        output_csv: Path to output CSV file
    """
    dataset_path = Path(dataset_root)

    # Prepare CSV
    with open(output_csv, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        # Write header
        writer.writerow(['image_path1', 'image_path2', 'age1', 'age2',
                        'embedding1', 'embedding2'])

        # Iterate through person folders
        person_folders = sorted([f for f in dataset_path.iterdir() if f.is_dir()])

        print(f"\nFound {len(person_folders)} person folders")
        print("="*60)

        total_pairs = 0
        successful_pairs = 0

        for person_folder in person_folders:
            person_name = person_folder.name
            print(f"\nProcessing {person_name}...")

            # Iterate through pair folders within each person folder
            pair_folders = sorted([f for f in person_folder.iterdir() if f.is_dir()])

            for pair_folder in pair_folders:
                pair_name = pair_folder.name
                print(f"  Processing pair: {pair_name}")

                # Get all image files in the pair folder
                image_files = sorted([f for f in pair_folder.iterdir()
                                    if f.suffix.lower() in ['.jpg', '.jpeg', '.png']])

                if len(image_files) != 2:
                    print(f"  ⚠ Expected 2 images, found {len(image_files)}. Skipping.")
                    continue

                total_pairs += 1

                img_path1 = str(image_files[0])
                img_path2 = str(image_files[1])

                # Process both images
                age1, embedding1 = process_image(img_path1)
                age2, embedding2 = process_image(img_path2)

                # Save if both images processed successfully
                if age1 is not None and age2 is not None:
                    writer.writerow([img_path1, img_path2, age1, age2,
                                   embedding1, embedding2])
                    successful_pairs += 1
                    print(f"  ✓ Success: Age1={age1:.1f}, Age2={age2:.1f}")
                else:
                    print(f"  ✗ Failed to process pair")

        print("\n" + "="*60)
        print(f"Processing complete!")
        print(f"Total pairs found: {total_pairs}")
        print(f"Successfully processed: {successful_pairs}")
        print(f"Failed: {total_pairs - successful_pairs}")
        print(f"Results saved to: {output_csv}")
        print("="*60)

# -----------------------------
# 3. Main Execution
# -----------------------------
if __name__ == "__main__":
    # Set your dataset path
    dataset_root = "MLP_dataset/Positive_FGNET"
    output_csv = "fgnet_preprocessing_results.csv"

    # Process the dataset
    process_dataset(dataset_root, output_csv)
# Out:
# Loading models...
# Age model already exists, skipping download...
# ✓ All models loaded!
#
# Found 82 person folders
# ============================================================
#
# Processing person001...
#   Processing pair: person001_02_14
#   ✓ Success: Age1=4.7, Age2=27.2
#   Processing pair: person001_02_16
#   ✓ Success: Age1=4.7, Age2=20.9
#   Processing pair: person001_02_18
#   ✓ Success: Age1=4.7, Age2=31.1
#   Processing pair: person001_02_19
#   ✓ Success: Age1=4.7, Age2=24.0
#   Processing pair: person001_02_22
#   ✓ Success: Age1=4.7, Age2=34.2
#   Processing pair: person001_02_28
#   ✓ Success: Age1=4.7, Age2=19.4
#   Processing pair: person001_02_29
#   ✓ Success: Age1=4.7, Age2=29.2
#   Processing pair: person001_02_33
#   ✓ Success: Age1=4.7, Age2=33.3
#   Processing pair: person001_02_40
#   ✓ Success: Age1=4.7, Age2=39.2
#   Processing pair: person001_05_16
#   ✓ Success: Age1=11.9, Age2=20.9
#   Processing pair: person001_05_18
#   ✓ Success: Age1=11.9, Age2=31.1
#   Processing pair: person001_05_19
#   ✓ Success: Age1=11.9, Age2=24.0
#   Processing pair: person001_05_22
#   ✓ Success: Age1=11.9, Age2=34.2
#   Processing pair: person001_05_28
#   ✓ Success: Age1=11.9, Age2=19.4
#   Processing pair: person001_05_29
#   ✓ Success: Age1=11.9, Age2=29.2
#   Processing pair: person001_05_33
#   ✓ Success: Age1=11.9, Age2=33.3
#   Processing pair: person001_05_40
#   ✓ Success: Age1=11.9, Age2=39.2
#   Processing pair: person001_08_19
#   ✓ Success: Age1=13.4, Age2=24.0
#   Processing pair: person001_08_22
#   ✓ Success: Age1=13.4, Age2=34.2
#   Processing pair: person001_08_28
#   ✓ Success: Age1=13.4, Age2=19.4
#   Processing pair: person001_08_29
#   ✓ Success: Age1=13.4, Age2=29.2
#   Processing pair: person001_08_33
#   ✓ Success: Age1=13.4, Age2=33.3
#   Processing pair: person001_08_40
#   ✓ Success: Age1=13.4, Age2=39.2
#   Processing pair: person001_10_22
#   ✓ Success: Age1=17.3, Age2=34.2
#   Processing pair: person001_10_28
#   ✓ Success: Age1=17.3, Age2=19.4
#   Processing pair: person001_10_29
#   ✓ Success: Age1=17.3, Age2=29.2
#   Processing pair: person001_10_33
#   ✓ Success: Age1=17.3, Age2=33.3
#   Processing pair: person001_10_40
#   ✓ Success: Age1=17.3, Age2=39.2
#   Processing pair: person001_14_28
#   ✓ Success: Age1=27.2, Age2=19.4
#   Processing pair: person001_14_29
#   ✓ Success: Age1=27.2, Age2=29.2
#   Processing pair: person001_14_33
#   ✓ Success: Age1=27.2, Age2=33.3
#   Processing pair: person001_14_40
#   ✓ Success: Age1=27.2, Age2=39.2
#   Processing pair: person001_16_28
#   ✓ Success: Age1=20.9, Age2=19.4
#   Processing pair: person001_16_29
#   ✓ Success: Age1=20.9, Age2=29.2
#   Processing pair: person001_16_33
#   ✓ Success: Age1=20.9, Age2=33.3
#   Processing pair: person001_16_40
#   ✓ Success: Age1=20.9, Age2=39.2
#   Processing pair: person001_18_29
#   ✓ Success: Age1=31.1, Age2=29.2
#   Processing pair: person001_18_33
#   ✓ Success: Age1=31.1, Age2=33.3
#   Processing pair: person001_18_40
#   ✓ Success: Age1=31.1, Age2=39.2
#   Processing pair: person001_19_33
#   ✓ Success: Age1=24.0, Age2=33.3
#   Processing pair: person001_19_40
#   ✓ Success: Age1=24.0, Age2=39.2
#   Processing pair: person001_22_33
#   ✓ Success: Age1=34.2, Age2=33.3
#   Processing pair: person001_22_40
#   ✓ Success: Age1=34.2, Age2=39.2
#   Processing pair: person001_28_40
#   ✓ Success: Age1=19.4, Age2=39.2
#   Processing pair: person001_29_40
#   ✓ Success: Age1=29.2, Age2=39.2
#
# Processing person002...
#   Processing pair: person002_03_15
#   ✓ Success: Age1=7.9, Age2=15.9
#   Processing pair: person002_03_16
#   ✓ Success: Age1=7.9, Age2=11.4
#   Processing pair: person002_03_18
#   ✓ Success: Age1=7.9, Age2=16.8
#   Processing pair: person002_03_20
#   ✓ Success: Age1=7.9, Age2=20.4
#   Processing pair: person002_03_21
#   ✓ Success: Age1=7.9, Age2=19.3
#   Processing pair: person002_03_23
#   ✓ Success: Age1=7.9, Age2=20.2
#   Processing pair: person002_03_26
#   ✓ Success: Age1=7.9, Age2=22.8
#   Processing pair: person002_03_29
#   ✓ Success: Age1=7.9, Age2=16.3
#   Processing pair: person002_03_31
#   ✓ Success: Age1=7.9, Age2=21.7
#   Processing pair: person002_03_36
#   ✓ Success: Age1=7.9, Age2=19.9
#   Processing pair: person002_03_38
#   ✓ Success: Age1=7.9, Age2=36.9
#   Processing pair: person002_04_15
#   ✓ Success: Age1=12.0, Age2=15.9
#   Processing pair: person002_04_16
#   ✓ Success: Age1=12.0, Age2=11.4
#   Processing pair: person002_04_18
#   ✓ Success: Age1=12.0, Age2=16.8
#   Processing pair: person002_04_20
#   ✓ Success: Age1=12.0, Age2=20.4
#   Processing pair: person002_04_21
#   ✓ Success: Age1=12.0, Age2=19.3
#   Processing pair: person002_04_23
#   ✓ Success: Age1=12.0, Age2=20.2
#   Processing pair: person002_04_26
#   ✓ Success: Age1=12.0, Age2=22.8
#   Processing pair: person002_04_29
#   ✓ Success: Age1=12.0, Age2=16.3
#   Processing pair: person002_04_31
#   ✓ Success: Age1=12.0, Age2=21.7
#   Processing pair: person002_04_36
#   ✓ Success: Age1=12.0, Age2=19.9
#   Processing pair: person002_04_38
#   ✓ Success: Age1=12.0, Age2=36.9
#   Processing pair: person002_05_16
#   ✓ Success: Age1=11.4, Age2=11.4
#   Processing pair: person002_05_18
#   ✓ Success: Age1=11.4, Age2=16.8
#   Processing pair: person002_05_20
#   ✓ Success: Age1=11.4, Age2=20.4
#   Processing pair: person002_05_21
#   ✓ Success: Age1=11.4, Age2=19.3
#   Processing pair: person002_05_23
#   ✓ Success: Age1=11.4, Age2=20.2
#   Processing pair: person002_05_26
#   ✓ Success: Age1=11.4, Age2=22.8
#   Processing pair: person002_05_29
#   ✓ Success: Age1=11.4, Age2=16.3
#   Processing pair: person002_05_31
#   ✓ Success: Age1=11.4, Age2=21.7
#   Processing pair: person002_05_36
#   ✓ Success: Age1=11.4, Age2=19.9
#   Processing pair: person002_05_38
#   ✓ Success: Age1=11.4, Age2=36.9
#   Processing pair: person002_07_18
#   ✓ Success: Age1=14.7, Age2=16.8
#   Processing pair: person002_07_20
#   ✓ Success: Age1=14.7, Age2=20.4
#   Processing pair: person002_07_21
#   ✓ Success: Age1=14.7, Age2=19.3
#   Processing pair: person002_07_23
#   ✓ Success: Age1=14.7, Age2=20.2
#   Processing pair: person002_07_26
#   ✓ Success: Age1=14.7, Age2=22.8
#   Processing pair: person002_07_29
#   ✓ Success: Age1=14.7, Age2=16.3
#   Processing pair: person002_07_31
#   ✓ Success: Age1=14.7, Age2=21.7
#   Processing pair: person002_07_36
#   ✓ Success: Age1=14.7, Age2=19.9
#   Processing pair: person002_07_38
#   ✓ Success: Age1=14.7, Age2=36.9
#   Processing pair: person002_12_23
#   ✓ Success: Age1=13.4, Age2=20.2
#   Processing pair: person002_12_26
#   ✓ Success: Age1=13.4, Age2=22.8
#   Processing pair: person002_12_29
#   ✓ Success: Age1=13.4, Age2=16.3
#   Processing pair: person002_12_31
#   ✓ Success: Age1=13.4, Age2=21.7
#   Processing pair: person002_12_36
#   ✓ Success: Age1=13.4, Age2=19.9
#   Processing pair: person002_12_38
#   ✓ Success: Age1=13.4, Age2=36.9
#   Processing pair: person002_15_26
#   ✓ Success: Age1=15.9, Age2=22.8
#   Processing pair: person002_15_29
#   ✓ Success: Age1=15.9, Age2=16.3
#   Processing pair: person002_15_31
#   ✓ Success: Age1=15.9, Age2=21.7
#   Processing pair: person002_15_36
#   ✓ Success: Age1=15.9, Age2=19.9
#   Processing pair: person002_15_38
#   ✓ Success: Age1=15.9, Age2=36.9
#   Processing pair: person002_16_29
#   ✓ Success: Age1=11.4, Age2=16.3
#   Processing pair: person002_16_31
#   ✓ Success: Age1=11.4, Age2=21.7
#   Processing pair: person002_16_36
#   ✓ Success: Age1=11.4, Age2=19.9
#   Processing pair: person002_16_38
#   ✓ Success: Age1=11.4, Age2=36.9
#   Processing pair: person002_18_29
#   ✓ Success: Age1=16.8, Age2=16.3
#   Processing pair: person002_18_31
#   ✓ Success: Age1=16.8, Age2=21.7
#   Processing pair: person002_18_36
#   ✓ Success: Age1=16.8, Age2=19.9
#   Processing pair: person002_18_38
#   ✓ Success: Age1=16.8, Age2=36.9
#   Processing pair: person002_20_31
#   ✓ Success: Age1=20.4, Age2=21.7
#   Processing pair: person002_20_36
#   ✓ Success: Age1=20.4, Age2=19.9
#   Processing pair: person002_20_38
#   ✓ Success: Age1=20.4, Age2=36.9
#   Processing pair: person002_21_36
#   ✓ Success: Age1=19.3, Age2=19.9
#   Processing pair: person002_21_38
#   ✓ Success: Age1=19.3, Age2=36.9
#   Processing pair: person002_23_36
#   ✓ Success: Age1=20.2, Age2=19.9
#   Processing pair: person002_23_38
#   ✓ Success: Age1=20.2, Age2=36.9
#   Processing pair: person002_26_38
#   ✓ Success: Age1=22.8, Age2=36.9
#
# Processing person003...
#   Processing pair: person003_18_35
#   ✓ Success: Age1=20.1, Age2=44.7
#   Processing pair: person003_18_38
#   ✓ Success: Age1=20.1, Age2=34.5
#   Processing pair: person003_18_47
#   ✓ Success: Age1=20.1, Age2=49.5
#   Processing pair: person003_18_49
#   ✓ Success: Age1=20.1, Age2=48.2
#   Processing pair: person003_18_51
#   ✓ Success: Age1=20.1, Age2=57.5
#   Processing pair: person003_18_58
#   ✓ Success: Age1=20.1, Age2=55.8
#   Processing pair: person003_18_60
#   ✓ Success: Age1=20.1, Age2=61.7
#   Processing pair: person003_18_61
#   ✓ Success: Age1=20.1, Age2=41.9
#   Processing pair: person003_20_35
#   ✓ Success: Age1=14.9, Age2=44.7
#   Processing pair: person003_20_38
#   ✓ Success: Age1=14.9, Age2=34.5
#   Processing pair: person003_20_47
#   ✓ Success: Age1=14.9, Age2=49.5
#   Processing pair: person003_20_49
#   ✓ Success: Age1=14.9, Age2=48.2
#   Processing pair: person003_20_51
#   ✓ Success: Age1=14.9, Age2=57.5
#   Processing pair: person003_20_58
#   ✓ Success: Age1=14.9, Age2=55.8
#   Processing pair: person003_20_60
#   ✓ Success: Age1=14.9, Age2=61.7
#   Processing pair: person003_20_61
#   ✓ Success: Age1=14.9, Age2=41.9
#   Processing pair: person003_23_35
#   ✓ Success: Age1=24.6, Age2=44.7
#   Processing pair: person003_23_38
#   ✓ Success: Age1=24.6, Age2=34.5
#   Processing pair: person003_23_47
#   ✓ Success: Age1=24.6, Age2=49.5
#   Processing pair: person003_23_49
#   ✓ Success: Age1=24.6, Age2=48.2
#   Processing pair: person003_23_51
#   ✓ Success: Age1=24.6, Age2=57.5
#   Processing pair: person003_23_58
#   ✓ Success: Age1=24.6, Age2=55.8
#   Processing pair: person003_23_60
#   ✓ Success: Age1=24.6, Age2=61.7
#   Processing pair: person003_23_61
#   ✓ Success: Age1=24.6, Age2=41.9
#   Processing pair: person003_25_38
#   ✓ Success: Age1=17.5, Age2=34.5
#   Processing pair: person003_25_47
#   ✓ Success: Age1=17.5, Age2=49.5
#   Processing pair: person003_25_49
#   ✓ Success: Age1=17.5, Age2=48.2
#   Processing pair: person003_25_51
#   ✓ Success: Age1=17.5, Age2=57.5
#   Processing pair: person003_25_58
#   ✓ Success: Age1=17.5, Age2=55.8
#   Processing pair: person003_25_60
#   ✓ Success: Age1=17.5, Age2=61.7
#   Processing pair: person003_25_61
#   ✓ Success: Age1=17.5, Age2=41.9
#   Processing pair: person003_35_47
#   ✓ Success: Age1=44.7, Age2=49.5
#   Processing pair: person003_35_49
#   ✓ Success: Age1=44.7, Age2=48.2
#   Processing pair: person003_35_51
#   ✓ Success: Age1=44.7, Age2=57.5
#   Processing pair: person003_35_58
#   ✓ Success: Age1=44.7, Age2=55.8
#   Processing pair: person003_35_60
#   ✓ Success: Age1=44.7, Age2=61.7
#   Processing pair: person003_35_61
#   ✓ Success: Age1=44.7, Age2=41.9
#   Processing pair: person003_38_49
#   ✓ Success: Age1=34.5, Age2=48.2
#   Processing pair: person003_38_51
#   ✓ Success: Age1=34.5, Age2=57.5
#   Processing pair: person003_38_58
#   ✓ Success: Age1=34.5, Age2=55.8
#   Processing pair: person003_38_60
#   ✓ Success: Age1=34.5, Age2=61.7
#   Processing pair: person003_38_61
#   ✓ Success: Age1=34.5, Age2=41.9
#   Processing pair: person003_47_58
#   ✓ Success: Age1=49.5, Age2=55.8
#   Processing pair: person003_47_60
#   ✓ Success: Age1=49.5, Age2=61.7
#   Processing pair: person003_47_61
#   ✓ Success: Age1=49.5, Age2=41.9
#   Processing pair: person003_49_60
#   ✓ Success: Age1=48.2, Age2=61.7
#   Processing pair: person003_49_61
#   ✓ Success: Age1=48.2, Age2=41.9
#
# Processing person004...
#   Processing pair: person004_19_30
#   ✓ Success: Age1=19.9, Age2=32.5
#   Processing pair: person004_19_37
#   ✓ Success: Age1=19.9, Age2=47.4
#   Processing pair: person004_19_40
#   ✓ Success: Age1=19.9, Age2=35.9
#   Processing pair: person004_19_48
#   ✓ Success: Age1=19.9, Age2=38.8
#   Processing pair: person004_19_51
#   ✓ Success: Age1=19.9, Age2=58.5
#   Processing pair: person004_19_53
#   ✓ Success: Age1=19.9, Age2=54.8
#   Processing pair: person004_19_62
#   ✓ Success: Age1=19.9, Age2=58.9
#   Processing pair: person004_19_63
#   ✓ Success: Age1=19.9, Age2=59.8
#   Processing pair: person004_21_37
#   ✓ Success: Age1=24.8, Age2=47.4
#   Processing pair: person004_21_40
#   ✓ Success: Age1=24.8, Age2=35.9
#   Processing pair: person004_21_48
#   ✓ Success: Age1=24.8, Age2=38.8
#   Processing pair: person004_21_51
#   ✓ Success: Age1=24.8, Age2=58.5
#   Processing pair: person004_21_53
#   ✓ Success: Age1=24.8, Age2=54.8
#   Processing pair: person004_21_62
#   ✓ Success: Age1=24.8, Age2=58.9
#   Processing pair: person004_21_63
#   ✓ Success: Age1=24.8, Age2=59.8
#   Processing pair: person004_26_37
#   ✓ Success: Age1=19.2, Age2=47.4
#   Processing pair: person004_26_40
#   ✓ Success: Age1=19.2, Age2=35.9
#   Processing pair: person004_26_48
#   ✓ Success: Age1=19.2, Age2=38.8
#   Processing pair: person004_26_51
#   ✓ Success: Age1=19.2, Age2=58.5
#   Processing pair: person004_26_53
#   ✓ Success: Age1=19.2, Age2=54.8
#   Processing pair: person004_26_62
#   ✓ Success: Age1=19.2, Age2=58.9
#   Processing pair: person004_26_63
#   ✓ Success: Age1=19.2, Age2=59.8
#   Processing pair: person004_28_40
#   ✓ Success: Age1=23.9, Age2=35.9
#   Processing pair: person004_28_48
#   ✓ Success: Age1=23.9, Age2=38.8
#   Processing pair: person004_28_51
#   ✓ Success: Age1=23.9, Age2=58.5
#   Processing pair: person004_28_53
#   ✓ Success: Age1=23.9, Age2=54.8
#   Processing pair: person004_28_62
#   ✓ Success: Age1=23.9, Age2=58.9
#   Processing pair: person004_28_63
#   ✓ Success: Age1=23.9, Age2=59.8
#   Processing pair: person004_30_48
#   ✓ Success: Age1=32.5, Age2=38.8
#   Processing pair: person004_30_51
#   ✓ Success: Age1=32.5, Age2=58.5
#   Processing pair: person004_30_53
#   ✓ Success: Age1=32.5, Age2=54.8
#   Processing pair: person004_30_62
#   ✓ Success: Age1=32.5, Age2=58.9
#   Processing pair: person004_30_63
#   ✓ Success: Age1=32.5, Age2=59.8
#   Processing pair: person004_37_48
#   ✓ Success: Age1=47.4, Age2=38.8
#   Processing pair: person004_37_51
#   ✓ Success: Age1=47.4, Age2=58.5
#   Processing pair: person004_37_53
#   ✓ Success: Age1=47.4, Age2=54.8
#   Processing pair: person004_37_62
#   ✓ Success: Age1=47.4, Age2=58.9
#   Processing pair: person004_37_63
#   ✓ Success: Age1=47.4, Age2=59.8
#   Processing pair: person004_40_51
#   ✓ Success: Age1=35.9, Age2=58.5
#   Processing pair: person004_40_53
#   ✓ Success: Age1=35.9, Age2=54.8
#   Processing pair: person004_40_62
#   ✓ Success: Age1=35.9, Age2=58.9
#   Processing pair: person004_40_63
#   ✓ Success: Age1=35.9, Age2=59.8
#   Processing pair: person004_48_62
#   ✓ Success: Age1=38.8, Age2=58.9
#   Processing pair: person004_48_63
#   ✓ Success: Age1=38.8, Age2=59.8
#   Processing pair: person004_51_62
#   ✓ Success: Age1=58.5, Age2=58.9
#   Processing pair: person004_51_63
#   ✓ Success: Age1=58.5, Age2=59.8
#
# Processing person005...
#   Processing pair: person005_18_30
#   ✓ Success: Age1=17.7, Age2=21.5
#   Processing pair: person005_18_31
#   ✓ Success: Age1=17.7, Age2=20.8
#   Processing pair: person005_18_35
#   ✓ Success: Age1=17.7, Age2=39.3
#   Processing pair: person005_18_40
#   ✓ Success: Age1=17.7, Age2=54.0
#   Processing pair: person005_18_45
#   ✓ Success: Age1=17.7, Age2=36.2
#   Processing pair: person005_18_48
#   ✓ Success: Age1=17.7, Age2=52.2
#   Processing pair: person005_18_49
#   ✓ Success: Age1=17.7, Age2=52.0
#   Processing pair: person005_18_52
#   ✓ Success: Age1=17.7, Age2=37.2
#   Processing pair: person005_18_61
#   ✓ Success: Age1=17.7, Age2=48.1
#   Processing pair: person005_24_35
#   ✓ Success: Age1=19.7, Age2=39.3
#   Processing pair: person005_24_40
#   ✓ Success: Age1=19.7, Age2=54.0
#   Processing pair: person005_24_45
#   ✓ Success: Age1=19.7, Age2=36.2
#   Processing pair: person005_24_48
#   ✓ Success: Age1=19.7, Age2=52.2
#   Processing pair: person005_24_49
#   ✓ Success: Age1=19.7, Age2=52.0
#   Processing pair: person005_24_52
#   ✓ Success: Age1=19.7, Age2=37.2
#   Processing pair: person005_24_61
#   ✓ Success: Age1=19.7, Age2=48.1
#   Processing pair: person005_30_45
#   ✓ Success: Age1=21.5, Age2=36.2
#   Processing pair: person005_30_48
#   ✓ Success: Age1=21.5, Age2=52.2
#   Processing pair: person005_30_49
#   ✓ Success: Age1=21.5, Age2=52.0
#   Processing pair: person005_30_52
#   ✓ Success: Age1=21.5, Age2=37.2
#   Processing pair: person005_30_61
#   ✓ Success: Age1=21.5, Age2=48.1
#   Processing pair: person005_31_45
#   ✓ Success: Age1=20.8, Age2=36.2
#   Processing pair: person005_31_48
#   ✓ Success: Age1=20.8, Age2=52.2
#   Processing pair: person005_31_49
#   ✓ Success: Age1=20.8, Age2=52.0
#   Processing pair: person005_31_52
#   ✓ Success: Age1=20.8, Age2=37.2
#   Processing pair: person005_31_61
#   ✓ Success: Age1=20.8, Age2=48.1
#   Processing pair: person005_35_48
#   ✓ Success: Age1=39.3, Age2=52.2
#   Processing pair: person005_35_49
#   ✓ Success: Age1=39.3, Age2=52.0
#   Processing pair: person005_35_52
#   ✓ Success: Age1=39.3, Age2=37.2
#   Processing pair: person005_35_61
#   ✓ Success: Age1=39.3, Age2=48.1
#   Processing pair: person005_40_52
#   ✓ Success: Age1=54.0, Age2=37.2
#   Processing pair: person005_40_61
#   ✓ Success: Age1=54.0, Age2=48.1
#   Processing pair: person005_45_61
#   ✓ Success: Age1=36.2, Age2=48.1
#   Processing pair: person005_48_61
#   ✓ Success: Age1=52.2, Age2=48.1
#   Processing pair: person005_49_61
#   ✓ Success: Age1=52.0, Age2=48.1
#
# Processing person006...
#   Processing pair: person006_24_36
#   ✓ Success: Age1=28.4, Age2=24.2
#   Processing pair: person006_24_40
#   ✓ Success: Age1=28.4, Age2=21.8
#   Processing pair: person006_24_42
#   ✓ Success: Age1=28.4, Age2=39.0
#   Processing pair: person006_24_46
#   ✓ Success: Age1=28.4, Age2=28.4
#   Processing pair: person006_24_51
#   ✓ Success: Age1=28.4, Age2=38.0
#   Processing pair: person006_24_55
#   ✓ Success: Age1=28.4, Age2=44.0
#   Processing pair: person006_24_61
#   ✓ Success: Age1=28.4, Age2=35.7
#   Processing pair: person006_24_67
#   ✓ Success: Age1=28.4, Age2=50.5
#   Processing pair: person006_24_69
#   ✓ Success: Age1=28.4, Age2=53.9
#   Processing pair: person006_28_40
#   ✓ Success: Age1=26.1, Age2=21.8
#   Processing pair: person006_28_42
#   ✓ Success: Age1=26.1, Age2=39.0
#   Processing pair: person006_28_46
#   ✓ Success: Age1=26.1, Age2=28.4
#   Processing pair: person006_28_51
#   ✓ Success: Age1=26.1, Age2=38.0
#   Processing pair: person006_28_55
#   ✓ Success: Age1=26.1, Age2=44.0
#   Processing pair: person006_28_61
#   ✓ Success: Age1=26.1, Age2=35.7
#   Processing pair: person006_28_67
#   ✓ Success: Age1=26.1, Age2=50.5
#   Processing pair: person006_28_69
#   ✓ Success: Age1=26.1, Age2=53.9
#   Processing pair: person006_31_42
#   ✓ Success: Age1=30.3, Age2=39.0
#   Processing pair: person006_31_46
#   ✓ Success: Age1=30.3, Age2=28.4
#   Processing pair: person006_31_51
#   ✓ Success: Age1=30.3, Age2=38.0
#   Processing pair: person006_31_55
#   ✓ Success: Age1=30.3, Age2=44.0
#   Processing pair: person006_31_61
#   ✓ Success: Age1=30.3, Age2=35.7
#   Processing pair: person006_31_67
#   ✓ Success: Age1=30.3, Age2=50.5
#   Processing pair: person006_31_69
#   ✓ Success: Age1=30.3, Age2=53.9
#   Processing pair: person006_36_51
#   ✓ Success: Age1=24.2, Age2=38.0
#   Processing pair: person006_36_55
#   ✓ Success: Age1=24.2, Age2=44.0
#   Processing pair: person006_36_61
#   ✓ Success: Age1=24.2, Age2=35.7
#   Processing pair: person006_36_67
#   ✓ Success: Age1=24.2, Age2=50.5
#   Processing pair: person006_36_69
#   ✓ Success: Age1=24.2, Age2=53.9
#   Processing pair: person006_40_51
#   ✓ Success: Age1=21.8, Age2=38.0
#   Processing pair: person006_40_55
#   ✓ Success: Age1=21.8, Age2=44.0
#   Processing pair: person006_40_61
#   ✓ Success: Age1=21.8, Age2=35.7
#   Processing pair: person006_40_67
#   ✓ Success: Age1=21.8, Age2=50.5
#   Processing pair: person006_40_69
#   ✓ Success: Age1=21.8, Age2=53.9
#   Processing pair: person006_42_55
#   ✓ Success: Age1=39.0, Age2=44.0
#   Processing pair: person006_42_61
#   ✓ Success: Age1=39.0, Age2=35.7
#   Processing pair: person006_42_67
#   ✓ Success: Age1=39.0, Age2=50.5
#   Processing pair: person006_42_69
#   ✓ Success: Age1=39.0, Age2=53.9
#   Processing pair: person006_46_61
#   ✓ Success: Age1=28.4, Age2=35.7
#   Processing pair: person006_46_67
#   ✓ Success: Age1=28.4, Age2=50.5
#   Processing pair: person006_46_69
#   ✓ Success: Age1=28.4, Age2=53.9
#   Processing pair: person006_51_67
#   ✓ Success: Age1=38.0, Age2=50.5
#   Processing pair: person006_51_69
#   ✓ Success: Age1=38.0, Age2=53.9
#   Processing pair: person006_55_67
#   ✓ Success: Age1=44.0, Age2=50.5
#   Processing pair: person006_55_69
#   ✓ Success: Age1=44.0, Age2=53.9
#
# Processing person007...
#   Processing pair: person007_01_18
#   ✓ Success: Age1=6.4, Age2=18.1
#   Processing pair: person007_01_22
#   ✓ Success: Age1=6.4, Age2=25.8
#   Processing pair: person007_01_23
#   ✓ Success: Age1=6.4, Age2=23.3
#   Processing pair: person007_01_26
#   ✓ Success: Age1=6.4, Age2=53.3
#   Processing pair: person007_01_37
#   ✓ Success: Age1=6.4, Age2=41.9
#   Processing pair: person007_01_38
#   ✓ Success: Age1=6.4, Age2=48.2
#   Processing pair: person007_01_39
#   ✓ Success: Age1=6.4, Age2=41.8
#   Processing pair: person007_01_45
#   ✓ Success: Age1=6.4, Age2=45.4
#   Processing pair: person007_18_37
#   ✓ Success: Age1=18.1, Age2=41.9
#   Processing pair: person007_18_38
#   ✓ Success: Age1=18.1, Age2=48.2
#   Processing pair: person007_18_39
#   ✓ Success: Age1=18.1, Age2=41.8
#   Processing pair: person007_18_45
#   ✓ Success: Age1=18.1, Age2=45.4
#   Processing pair: person007_22_37
#   ✓ Success: Age1=25.8, Age2=41.9
#   Processing pair: person007_22_38
#   ✓ Success: Age1=25.8, Age2=48.2
#   Processing pair: person007_22_39
#   ✓ Success: Age1=25.8, Age2=41.8
#   Processing pair: person007_22_45
#   ✓ Success: Age1=25.8, Age2=45.4
#   Processing pair: person007_23_37
#   ✓ Success: Age1=23.3, Age2=41.9
#   Processing pair: person007_23_38
#   ✓ Success: Age1=23.3, Age2=48.2
#   Processing pair: person007_23_39
#   ✓ Success: Age1=23.3, Age2=41.8
#   Processing pair: person007_23_45
#   ✓ Success: Age1=23.3, Age2=45.4
#   Processing pair: person007_26_37
#   ✓ Success: Age1=53.3, Age2=41.9
#   Processing pair: person007_26_38
#   ✓ Success: Age1=53.3, Age2=48.2
#   Processing pair: person007_26_39
#   ✓ Success: Age1=53.3, Age2=41.8
#   Processing pair: person007_26_45
#   ✓ Success: Age1=53.3, Age2=45.4
#
# Processing person008...
#   Processing pair: person008_03_16
#   ✓ Success: Age1=10.5, Age2=29.6
#   Processing pair: person008_03_17
#   ✓ Success: Age1=10.5, Age2=18.7
#   Processing pair: person008_03_18
#   ✓ Success: Age1=10.5, Age2=25.6
#   Processing pair: person008_03_21
#   ✓ Success: Age1=10.5, Age2=24.6
#   Processing pair: person008_03_29
#   ✓ Success: Age1=10.5, Age2=28.4
#   Processing pair: person008_03_30
#   ✓ Success: Age1=10.5, Age2=21.9
#   Processing pair: person008_03_31
#   ✓ Success: Age1=10.5, Age2=31.4
#   Processing pair: person008_03_33
#   ✓ Success: Age1=10.5, Age2=27.0
#   Processing pair: person008_03_35
#   ✓ Success: Age1=10.5, Age2=25.0
#   Processing pair: person008_03_41
#   ✓ Success: Age1=10.5, Age2=36.6
#   Processing pair: person008_06_17
#   ✓ Success: Age1=13.0, Age2=18.7
#   Processing pair: person008_06_18
#   ✓ Success: Age1=13.0, Age2=25.6
#   Processing pair: person008_06_21
#   ✓ Success: Age1=13.0, Age2=24.6
#   Processing pair: person008_06_29
#   ✓ Success: Age1=13.0, Age2=28.4
#   Processing pair: person008_06_30
#   ✓ Success: Age1=13.0, Age2=21.9
#   Processing pair: person008_06_31
#   ✓ Success: Age1=13.0, Age2=31.4
#   Processing pair: person008_06_33
#   ✓ Success: Age1=13.0, Age2=27.0
#   Processing pair: person008_06_35
#   ✓ Success: Age1=13.0, Age2=25.0
#   Processing pair: person008_06_41
#   ✓ Success: Age1=13.0, Age2=36.6
#   Processing pair: person008_08_21
#   ✓ Success: Age1=12.6, Age2=24.6
#   Processing pair: person008_08_29
#   ✓ Success: Age1=12.6, Age2=28.4
#   Processing pair: person008_08_30
#   ✓ Success: Age1=12.6, Age2=21.9
#   Processing pair: person008_08_31
#   ✓ Success: Age1=12.6, Age2=31.4
#   Processing pair: person008_08_33
#   ✓ Success: Age1=12.6, Age2=27.0
#   Processing pair: person008_08_35
#   ✓ Success: Age1=12.6, Age2=25.0
#   Processing pair: person008_08_41
#   ✓ Success: Age1=12.6, Age2=36.6
#   Processing pair: person008_12_29
#   ✓ Success: Age1=12.3, Age2=28.4
#   Processing pair: person008_12_30
#   ✓ Success: Age1=12.3, Age2=21.9
#   Processing pair: person008_12_31
#   ✓ Success: Age1=12.3, Age2=31.4
#   Processing pair: person008_12_33
#   ✓ Success: Age1=12.3, Age2=27.0
#   Processing pair: person008_12_35
#   ✓ Success: Age1=12.3, Age2=25.0
#   Processing pair: person008_12_41
#   ✓ Success: Age1=12.3, Age2=36.6
#   Processing pair: person008_13_29
#   ✓ Success: Age1=17.0, Age2=28.4
#   Processing pair: person008_13_30
#   ✓ Success: Age1=17.0, Age2=21.9
#   Processing pair: person008_13_31
#   ✓ Success: Age1=17.0, Age2=31.4
#   Processing pair: person008_13_33
#   ✓ Success: Age1=17.0, Age2=27.0
#   Processing pair: person008_13_35
#   ✓ Success: Age1=17.0, Age2=25.0
#   Processing pair: person008_13_41
#   ✓ Success: Age1=17.0, Age2=36.6
#   Processing pair: person008_16_29
#   ✓ Success: Age1=29.6, Age2=28.4
#   Processing pair: person008_16_30
#   ✓ Success: Age1=29.6, Age2=21.9
#   Processing pair: person008_16_31
#   ✓ Success: Age1=29.6, Age2=31.4
#   Processing pair: person008_16_33
#   ✓ Success: Age1=29.6, Age2=27.0
#   Processing pair: person008_16_35
#   ✓ Success: Age1=29.6, Age2=25.0
#   Processing pair: person008_16_41
#   ✓ Success: Age1=29.6, Age2=36.6
#   Processing pair: person008_17_29
#   ✓ Success: Age1=18.7, Age2=28.4
#   Processing pair: person008_17_30
#   ✓ Success: Age1=18.7, Age2=21.9
#   Processing pair: person008_17_31
#   ✓ Success: Age1=18.7, Age2=31.4
#   Processing pair: person008_17_33
#   ✓ Success: Age1=18.7, Age2=27.0
#   Processing pair: person008_17_35
#   ✓ Success: Age1=18.7, Age2=25.0
#   Processing pair: person008_17_41
#   ✓ Success: Age1=18.7, Age2=36.6
#   Processing pair: person008_18_29
#   ✓ Success: Age1=25.6, Age2=28.4
#   Processing pair: person008_18_30
#   ✓ Success: Age1=25.6, Age2=21.9
#   Processing pair: person008_18_31
#   ✓ Success: Age1=25.6, Age2=31.4
#   Processing pair: person008_18_33
#   ✓ Success: Age1=25.6, Age2=27.0
#   Processing pair: person008_18_35
#   ✓ Success: Age1=25.6, Age2=25.0
#   Processing pair: person008_18_41
#   ✓ Success: Age1=25.6, Age2=36.6
#   Processing pair: person008_21_33
#   ✓ Success: Age1=24.6, Age2=27.0
#   Processing pair: person008_21_35
#   ✓ Success: Age1=24.6, Age2=25.0
#   Processing pair: person008_21_41
#   ✓ Success: Age1=24.6, Age2=36.6
#   Processing pair: person008_29_41
#   ✓ Success: Age1=28.4, Age2=36.6
#   Processing pair: person008_30_41
#   ✓ Success: Age1=21.9, Age2=36.6
#
# Processing person009...
#   Processing pair: person009_00_11
#   ✓ Success: Age1=5.6, Age2=17.5
#   Processing pair: person009_00_13
#   ✓ Success: Age1=5.6, Age2=18.9
#   Processing pair: person009_00_14
#   ✓ Success: Age1=5.6, Age2=16.7
#   Processing pair: person009_00_18
#   ✓ Success: Age1=5.6, Age2=23.1
#   Processing pair: person009_01_13
#   ✓ Success: Age1=8.8, Age2=18.9
#   Processing pair: person009_01_14
#   ✓ Success: Age1=8.8, Age2=16.7
#   Processing pair: person009_01_18
#   ✓ Success: Age1=8.8, Age2=23.1
#   Processing pair: person009_03_14
#   ✓ Success: Age1=7.5, Age2=16.7
#   Processing pair: person009_03_18
#   ✓ Success: Age1=7.5, Age2=23.1
#   Processing pair: person009_05_18
#   ✓ Success: Age1=13.8, Age2=23.1
#
# Processing person010...
#   Processing pair: person010_01_12
#   ✓ Success: Age1=2.5, Age2=21.1
#   Processing pair: person010_01_15
#   ✓ Success: Age1=2.5, Age2=24.6
#   Processing pair: person010_01_16
#   ✓ Success: Age1=2.5, Age2=23.3
#   Processing pair: person010_01_18
#   ✓ Success: Age1=2.5, Age2=21.1
#   Processing pair: person010_04_15
#   ✓ Success: Age1=10.5, Age2=24.6
#   Processing pair: person010_04_16
#   ✓ Success: Age1=10.5, Age2=23.3
#   Processing pair: person010_04_18
#   ✓ Success: Age1=10.5, Age2=21.1
#   Processing pair: person010_05_16
#   ✓ Success: Age1=11.4, Age2=23.3
#   Processing pair: person010_05_18
#   ✓ Success: Age1=11.4, Age2=21.1
#   Processing pair: person010_06_18
#   ✓ Success: Age1=9.3, Age2=21.1
#
# Processing person011...
#   Processing pair: person011_02_13
#   ✓ Success: Age1=7.9, Age2=18.3
#   Processing pair: person011_02_14
#   ✓ Success: Age1=7.9, Age2=17.9
#   Processing pair: person011_02_15
#   ✓ Success: Age1=7.9, Age2=28.6
#   Processing pair: person011_02_17
#   ✓ Success: Age1=7.9, Age2=16.6
#   Processing pair: person011_02_20
#   ✓ Success: Age1=7.9, Age2=26.5
#   Processing pair: person011_02_27
#   ✓ Success: Age1=7.9, Age2=26.7
#   Processing pair: person011_02_30
#   ✓ Success: Age1=7.9, Age2=22.5
#   Processing pair: person011_02_34
#   ✓ Success: Age1=7.9, Age2=27.9
#   Processing pair: person011_02_40
#   ✓ Success: Age1=7.9, Age2=30.7
#   Processing pair: person011_02_42
#   ✓ Success: Age1=7.9, Age2=21.9
#   Processing pair: person011_05_17
#   ✓ Success: Age1=11.8, Age2=16.6
#   Processing pair: person011_05_20
#   ✓ Success: Age1=11.8, Age2=26.5
#   Processing pair: person011_05_27
#   ✓ Success: Age1=11.8, Age2=26.7
#   Processing pair: person011_05_30
#   ✓ Success: Age1=11.8, Age2=22.5
#   Processing pair: person011_05_34
#   ✓ Success: Age1=11.8, Age2=27.9
#   Processing pair: person011_05_40
#   ✓ Success: Age1=11.8, Age2=30.7
#   Processing pair: person011_05_42
#   ✓ Success: Age1=11.8, Age2=21.9
#   Processing pair: person011_07_20
#   ✓ Success: Age1=12.1, Age2=26.5
#   Processing pair: person011_07_27
#   ✓ Success: Age1=12.1, Age2=26.7
#   Processing pair: person011_07_30
#   ✓ Success: Age1=12.1, Age2=22.5
#   Processing pair: person011_07_34
#   ✓ Success: Age1=12.1, Age2=27.9
#   Processing pair: person011_07_40
#   ✓ Success: Age1=12.1, Age2=30.7
#   Processing pair: person011_07_42
#   ✓ Success: Age1=12.1, Age2=21.9
#   Processing pair: person011_11_27
#   ✓ Success: Age1=9.9, Age2=26.7
#   Processing pair: person011_11_30
#   ✓ Success: Age1=9.9, Age2=22.5
#   Processing pair: person011_11_34
#   ✓ Success: Age1=9.9, Age2=27.9
#   Processing pair: person011_11_40
#   ✓ Success: Age1=9.9, Age2=30.7
#   Processing pair: person011_11_42
#   ✓ Success: Age1=9.9, Age2=21.9
#   Processing pair: person011_13_27
#   ✓ Success: Age1=18.3, Age2=26.7
#   Processing pair: person011_13_30
#   ✓ Success: Age1=18.3, Age2=22.5
#   Processing pair: person011_13_34
#   ✓ Success: Age1=18.3, Age2=27.9
#   Processing pair: person011_13_40
#   ✓ Success: Age1=18.3, Age2=30.7
#   Processing pair: person011_13_42
#   ✓ Success: Age1=18.3, Age2=21.9
#   Processing pair: person011_14_27
#   ✓ Success: Age1=17.9, Age2=26.7
#   Processing pair: person011_14_30
#   ✓ Success: Age1=17.9, Age2=22.5
#   Processing pair: person011_14_34
#   ✓ Success: Age1=17.9, Age2=27.9
#   Processing pair: person011_14_40
#   ✓ Success: Age1=17.9, Age2=30.7
#   Processing pair: person011_14_42
#   ✓ Success: Age1=17.9, Age2=21.9
#   Processing pair: person011_15_27
#   ✓ Success: Age1=28.6, Age2=26.7
#   Processing pair: person011_15_30
#   ✓ Success: Age1=28.6, Age2=22.5
#   Processing pair: person011_15_34
#   ✓ Success: Age1=28.6, Age2=27.9
#   Processing pair: person011_15_40
#   ✓ Success: Age1=28.6, Age2=30.7
#   Processing pair: person011_15_42
#   ✓ Success: Age1=28.6, Age2=21.9
#   Processing pair: person011_17_30
#   ✓ Success: Age1=16.6, Age2=22.5
#   Processing pair: person011_17_34
#   ✓ Success: Age1=16.6, Age2=27.9
#   Processing pair: person011_17_40
#   ✓ Success: Age1=16.6, Age2=30.7
#   Processing pair: person011_17_42
#   ✓ Success: Age1=16.6, Age2=21.9
#   Processing pair: person011_20_34
#   ✓ Success: Age1=26.5, Age2=27.9
#   Processing pair: person011_20_40
#   ✓ Success: Age1=26.5, Age2=30.7
#   Processing pair: person011_20_42
#   ✓ Success: Age1=26.5, Age2=21.9
#   Processing pair: person011_27_40
#   ✓ Success: Age1=26.7, Age2=30.7
#   Processing pair: person011_27_42
#   ✓ Success: Age1=26.7, Age2=21.9
#   Processing pair: person011_30_42
#   ✓ Success: Age1=22.5, Age2=21.9
#
# Processing person012...
#   Processing pair: person012_04_18
#   ✓ Success: Age1=9.7, Age2=26.9
#   Processing pair: person012_04_21
#   ✓ Success: Age1=9.7, Age2=34.5
#   Processing pair: person012_04_23
#   ✓ Success: Age1=9.7, Age2=27.6
#   Processing pair: person012_04_24
#   ✓ Success: Age1=9.7, Age2=26.1
#   Processing pair: person012_04_25
#   ✓ Success: Age1=9.7, Age2=23.7
#   Processing pair: person012_04_26
#   ✓ Success: Age1=9.7, Age2=24.5
#   Processing pair: person012_04_27
#   ✓ Success: Age1=9.7, Age2=33.4
#   Processing pair: person012_04_30
#   ✓ Success: Age1=9.7, Age2=25.8
#   Processing pair: person012_04_32
#   ✓ Success: Age1=9.7, Age2=39.1
#   Processing pair: person012_04_34
#   ✓ Success: Age1=9.7, Age2=30.2
#   Processing pair: person012_04_36
#   ✓ Success: Age1=9.7, Age2=21.6
#   Processing pair: person012_07_18
#   ✓ Success: Age1=21.0, Age2=26.9
#   Processing pair: person012_07_21
#   ✓ Success: Age1=21.0, Age2=34.5
#   Processing pair: person012_07_23
#   ✓ Success: Age1=21.0, Age2=27.6
#   Processing pair: person012_07_24
#   ✓ Success: Age1=21.0, Age2=26.1
#   Processing pair: person012_07_25
#   ✓ Success: Age1=21.0, Age2=23.7
#   Processing pair: person012_07_26
#   ✓ Success: Age1=21.0, Age2=24.5
#   Processing pair: person012_07_27
#   ✓ Success: Age1=21.0, Age2=33.4
#   Processing pair: person012_07_30
#   ✓ Success: Age1=21.0, Age2=25.8
#   Processing pair: person012_07_32
#   ✓ Success: Age1=21.0, Age2=39.1
#   Processing pair: person012_07_34
#   ✓ Success: Age1=21.0, Age2=30.2
#   Processing pair: person012_07_36
#   ✓ Success: Age1=21.0, Age2=21.6
#   Processing pair: person012_12_23
#   ✓ Success: Age1=15.1, Age2=27.6
#   Processing pair: person012_12_24
#   ✓ Success: Age1=15.1, Age2=26.1
#   Processing pair: person012_12_25
#   ✓ Success: Age1=15.1, Age2=23.7
#   Processing pair: person012_12_26
#   ✓ Success: Age1=15.1, Age2=24.5
#   Processing pair: person012_12_27
#   ✓ Success: Age1=15.1, Age2=33.4
#   Processing pair: person012_12_30
#   ✓ Success: Age1=15.1, Age2=25.8
#   Processing pair: person012_12_32
#   ✓ Success: Age1=15.1, Age2=39.1
#   Processing pair: person012_12_34
#   ✓ Success: Age1=15.1, Age2=30.2
#   Processing pair: person012_12_36
#   ✓ Success: Age1=15.1, Age2=21.6
#   Processing pair: person012_14_25
#   ✓ Success: Age1=29.5, Age2=23.7
#   Processing pair: person012_14_26
#   ✓ Success: Age1=29.5, Age2=24.5
#   Processing pair: person012_14_27
#   ✓ Success: Age1=29.5, Age2=33.4
#   Processing pair: person012_14_30
#   ✓ Success: Age1=29.5, Age2=25.8
#   Processing pair: person012_14_32
#   ✓ Success: Age1=29.5, Age2=39.1
#   Processing pair: person012_14_34
#   ✓ Success: Age1=29.5, Age2=30.2
#   Processing pair: person012_14_36
#   ✓ Success: Age1=29.5, Age2=21.6
#   Processing pair: person012_18_30
#   ✓ Success: Age1=26.9, Age2=25.8
#   Processing pair: person012_18_32
#   ✓ Success: Age1=26.9, Age2=39.1
#   Processing pair: person012_18_34
#   ✓ Success: Age1=26.9, Age2=30.2
#   Processing pair: person012_18_36
#   ✓ Success: Age1=26.9, Age2=21.6
#   Processing pair: person012_21_32
#   ✓ Success: Age1=34.5, Age2=39.1
#   Processing pair: person012_21_34
#   ✓ Success: Age1=34.5, Age2=30.2
#   Processing pair: person012_21_36
#   ✓ Success: Age1=34.5, Age2=21.6
#   Processing pair: person012_23_34
#   ✓ Success: Age1=27.6, Age2=30.2
#   Processing pair: person012_23_36
#   ✓ Success: Age1=27.6, Age2=21.6
#   Processing pair: person012_24_36
#   ✓ Success: Age1=26.1, Age2=21.6
#   Processing pair: person012_25_36
#   ✓ Success: Age1=23.7, Age2=21.6
#
# Processing person013...
#   Processing pair: person013_00_16
#   ✓ Success: Age1=4.7, Age2=26.5
#   Processing pair: person013_00_18
#   ✓ Success: Age1=4.7, Age2=20.3
#   Processing pair: person013_00_19
#   ✓ Success: Age1=4.7, Age2=27.6
#   Processing pair: person013_00_21
#   ✓ Success: Age1=4.7, Age2=25.5
#   Processing pair: person013_00_23
#   ✓ Success: Age1=4.7, Age2=30.8
#   Processing pair: person013_00_25
#   ✓ Success: Age1=4.7, Age2=20.6
#   Processing pair: person013_00_30
#   ✓ Success: Age1=4.7, Age2=37.2
#   Processing pair: person013_00_34
#   ✓ Success: Age1=4.7, Age2=32.7
#   Processing pair: person013_00_41
#   ✓ Success: Age1=4.7, Age2=38.0
#   Processing pair: person013_00_44
#   ✓ Success: Age1=4.7, Age2=42.5
#   Processing pair: person013_08_19
#   ✓ Success: Age1=14.3, Age2=27.6
#   Processing pair: person013_08_21
#   ✓ Success: Age1=14.3, Age2=25.5
#   Processing pair: person013_08_23
#   ✓ Success: Age1=14.3, Age2=30.8
#   Processing pair: person013_08_25
#   ✓ Success: Age1=14.3, Age2=20.6
#   Processing pair: person013_08_30
#   ✓ Success: Age1=14.3, Age2=37.2
#   Processing pair: person013_08_34
#   ✓ Success: Age1=14.3, Age2=32.7
#   Processing pair: person013_08_41
#   ✓ Success: Age1=14.3, Age2=38.0
#   Processing pair: person013_08_44
#   ✓ Success: Age1=14.3, Age2=42.5
#   Processing pair: person013_16_30
#   ✓ Success: Age1=26.5, Age2=37.2
#   Processing pair: person013_16_34
#   ✓ Success: Age1=26.5, Age2=32.7
#   Processing pair: person013_16_41
#   ✓ Success: Age1=26.5, Age2=38.0
#   Processing pair: person013_16_44
#   ✓ Success: Age1=26.5, Age2=42.5
#   Processing pair: person013_18_30
#   ✓ Success: Age1=20.3, Age2=37.2
#   Processing pair: person013_18_34
#   ✓ Success: Age1=20.3, Age2=32.7
#   Processing pair: person013_18_41
#   ✓ Success: Age1=20.3, Age2=38.0
#   Processing pair: person013_18_44
#   ✓ Success: Age1=20.3, Age2=42.5
#   Processing pair: person013_19_30
#   ✓ Success: Age1=27.6, Age2=37.2
#   Processing pair: person013_19_34
#   ✓ Success: Age1=27.6, Age2=32.7
#   Processing pair: person013_19_41
#   ✓ Success: Age1=27.6, Age2=38.0
#   Processing pair: person013_19_44
#   ✓ Success: Age1=27.6, Age2=42.5
#   Processing pair: person013_21_34
#   ✓ Success: Age1=25.5, Age2=32.7
#   Processing pair: person013_21_41
#   ✓ Success: Age1=25.5, Age2=38.0
#   Processing pair: person013_21_44
#   ✓ Success: Age1=25.5, Age2=42.5
#   Processing pair: person013_23_34
#   ✓ Success: Age1=30.8, Age2=32.7
#   Processing pair: person013_23_41
#   ✓ Success: Age1=30.8, Age2=38.0
#   Processing pair: person013_23_44
#   ✓ Success: Age1=30.8, Age2=42.5
#   Processing pair: person013_25_41
#   ✓ Success: Age1=20.6, Age2=38.0
#   Processing pair: person013_25_44
#   ✓ Success: Age1=20.6, Age2=42.5
#   Processing pair: person013_30_41
#   ✓ Success: Age1=37.2, Age2=38.0
#   Processing pair: person013_30_44
#   ✓ Success: Age1=37.2, Age2=42.5
#
# Processing person014...
#   Processing pair: person014_03_14
#   ⚠ No face detected in MLP_dataset/Positive_FGNET/person014/person014_03_14/014A03.JPG
#   ✗ Failed to process pair
#   Processing pair: person014_03_16
#   ⚠ No face detected in MLP_dataset/Positive_FGNET/person014/person014_03_16/014A03.JPG
#   ✗ Failed to process pair
#   Processing pair: person014_03_18
#   ⚠ No face detected in MLP_dataset/Positive_FGNET/person014/person014_03_18/014A03.JPG
#   ✗ Failed to process pair
#   Processing pair: person014_03_22
#   ⚠ No face detected in MLP_dataset/Positive_FGNET/person014/person014_03_22/014A03.JPG
#   ✗ Failed to process pair
#   Processing pair: person014_03_30
#   ⚠ No face detected in MLP_dataset/Positive_FGNET/person014/person014_03_30/014A03.JPG
#   ✗ Failed to process pair
#   Processing pair: person014_03_36
#   ⚠ No face detected in MLP_dataset/Positive_FGNET/person014/person014_03_36/014A03.JPG
#   ✗ Failed to process pair
#   Processing pair: person014_03_40
#   ⚠ No face detected in MLP_dataset/Positive_FGNET/person014/person014_03_40/014A03.JPG
#   ✗ Failed to process pair
#   Processing pair: person014_03_42
#   ⚠ No face detected in MLP_dataset/Positive_FGNET/person014/person014_03_42/014A03.JPG
#   ✗ Failed to process pair
#   Processing pair: person014_12_30
#   ✓ Success: Age1=15.4, Age2=25.4
#   Processing pair: person014_12_36
#   ✓ Success: Age1=15.4, Age2=36.6
#   Processing pair: person014_12_40
#   ✓ Success: Age1=15.4, Age2=30.8
#   Processing pair: person014_12_42
#   ✓ Success: Age1=15.4, Age2=32.6
#   Processing pair: person014_14_30
#   ✓ Success: Age1=33.1, Age2=25.4
#   Processing pair: person014_14_36
#   ✓ Success: Age1=33.1, Age2=36.6
#   Processing pair: person014_14_40
#   ✓ Success: Age1=33.1, Age2=30.8
#   Processing pair: person014_14_42
#   ✓ Success: Age1=33.1, Age2=32.6
#   Processing pair: person014_16_30
#   ✓ Success: Age1=20.5, Age2=25.4
#   Processing pair: person014_16_36
#   ✓ Success: Age1=20.5, Age2=36.6
#   Processing pair: person014_16_40
#   ✓ Success: Age1=20.5, Age2=30.8
#   Processing pair: person014_16_42
#   ✓ Success: Age1=20.5, Age2=32.6
#   Processing pair: person014_18_30
#   ✓ Success: Age1=18.4, Age2=25.4
#   Processing pair: person014_18_36
#   ✓ Success: Age1=18.4, Age2=36.6
#   Processing pair: person014_18_40
#   ✓ Success: Age1=18.4, Age2=30.8
#   Processing pair: person014_18_42
#   ✓ Success: Age1=18.4, Age2=32.6
#   Processing pair: person014_22_36
#   ✓ Success: Age1=18.5, Age2=36.6
#   Processing pair: person014_22_40
#   ✓ Success: Age1=18.5, Age2=30.8
#   Processing pair: person014_22_42
#   ✓ Success: Age1=18.5, Age2=32.6
#   Processing pair: person014_30_42
#   ✓ Success: Age1=25.4, Age2=32.6
#
# Processing person015...
#   Processing pair: person015_00_12
#   ✓ Success: Age1=6.2, Age2=15.7
#   Processing pair: person015_00_14
#   ✓ Success: Age1=6.2, Age2=16.2
#   Processing pair: person015_00_15
#   ✓ Success: Age1=6.2, Age2=18.2
#   Processing pair: person015_00_17
#   ✓ Success: Age1=6.2, Age2=17.5
#   Processing pair: person015_00_19
#   ✓ Success: Age1=6.2, Age2=24.5
#   Processing pair: person015_01_12
#   ✓ Success: Age1=7.3, Age2=15.7
#   Processing pair: person015_01_14
#   ✓ Success: Age1=7.3, Age2=16.2
#   Processing pair: person015_01_15
#   ✓ Success: Age1=7.3, Age2=18.2
#   Processing pair: person015_01_17
#   ✓ Success: Age1=7.3, Age2=17.5
#   Processing pair: person015_01_19
#   ✓ Success: Age1=7.3, Age2=24.5
#   Processing pair: person015_03_14
#   ✓ Success: Age1=6.4, Age2=16.2
#   Processing pair: person015_03_15
#   ✓ Success: Age1=6.4, Age2=18.2
#   Processing pair: person015_03_17
#   ✓ Success: Age1=6.4, Age2=17.5
#   Processing pair: person015_03_19
#   ✓ Success: Age1=6.4, Age2=24.5
#   Processing pair: person015_04_15
#   ✓ Success: Age1=13.4, Age2=18.2
#   Processing pair: person015_04_17
#   ✓ Success: Age1=13.4, Age2=17.5
#   Processing pair: person015_04_19
#   ✓ Success: Age1=13.4, Age2=24.5
#   Processing pair: person015_05_17
#   ✓ Success: Age1=12.5, Age2=17.5
#   Processing pair: person015_05_19
#   ✓ Success: Age1=12.5, Age2=24.5
#   Processing pair: person015_07_19
#   ✓ Success: Age1=13.8, Age2=24.5
#
# Processing person016...
#   Processing pair: person016_01_12
#   ✓ Success: Age1=4.6, Age2=19.1
#   Processing pair: person016_01_14
#   ✓ Success: Age1=4.6, Age2=25.6
#   Processing pair: person016_01_16
#   ✓ Success: Age1=4.6, Age2=17.9
#   Processing pair: person016_01_17
#   ✓ Success: Age1=4.6, Age2=13.9
#   Processing pair: person016_01_18
#   ✓ Success: Age1=4.6, Age2=27.9
#   Processing pair: person016_01_19
#   ✓ Success: Age1=4.6, Age2=17.4
#   Processing pair: person016_03_14
#   ✓ Success: Age1=8.5, Age2=25.6
#   Processing pair: person016_03_16
#   ✓ Success: Age1=8.5, Age2=17.9
#   Processing pair: person016_03_17
#   ✓ Success: Age1=8.5, Age2=13.9
#   Processing pair: person016_03_18
#   ✓ Success: Age1=8.5, Age2=27.9
#   Processing pair: person016_03_19
#   ✓ Success: Age1=8.5, Age2=17.4
#   Processing pair: person016_04_16
#   ✓ Success: Age1=8.6, Age2=17.9
#   Processing pair: person016_04_17
#   ✓ Success: Age1=8.6, Age2=13.9
#   Processing pair: person016_04_18
#   ✓ Success: Age1=8.6, Age2=27.9
#   Processing pair: person016_04_19
#   ✓ Success: Age1=8.6, Age2=17.4
#   Processing pair: person016_05_16
#   ✓ Success: Age1=16.1, Age2=17.9
#   Processing pair: person016_05_17
#   ✓ Success: Age1=16.1, Age2=13.9
#   Processing pair: person016_05_18
#   ✓ Success: Age1=16.1, Age2=27.9
#   Processing pair: person016_05_19
#   ✓ Success: Age1=16.1, Age2=17.4
#   Processing pair: person016_07_18
#   ✓ Success: Age1=18.7, Age2=27.9
#   Processing pair: person016_07_19
#   ✓ Success: Age1=18.7, Age2=17.4
#   Processing pair: person016_08_19
#   ✓ Success: Age1=7.7, Age2=17.4
#
# Processing person017...
#   Processing pair: person017_05_17
#   ✓ Success: Age1=6.1, Age2=23.1
#   Processing pair: person017_05_19
#   ✓ Success: Age1=6.1, Age2=24.5
#   Processing pair: person017_05_22
#   ✓ Success: Age1=6.1, Age2=31.7
#   Processing pair: person017_05_26
#   ✓ Success: Age1=6.1, Age2=24.2
#   Processing pair: person017_05_29
#   ✓ Success: Age1=6.1, Age2=35.5
#   Processing pair: person017_05_32
#   ✓ Success: Age1=6.1, Age2=27.0
#   Processing pair: person017_05_36
#   ✓ Success: Age1=6.1, Age2=22.7
#   Processing pair: person017_05_38
#   ✓ Success: Age1=6.1, Age2=35.8
#   Processing pair: person017_05_42
#   ✓ Success: Age1=6.1, Age2=46.3
#   Processing pair: person017_07_19
#   ✓ Success: Age1=24.0, Age2=24.5
#   Processing pair: person017_07_22
#   ✓ Success: Age1=24.0, Age2=31.7
#   Processing pair: person017_07_26
#   ✓ Success: Age1=24.0, Age2=24.2
#   Processing pair: person017_07_29
#   ✓ Success: Age1=24.0, Age2=35.5
#   Processing pair: person017_07_32
#   ✓ Success: Age1=24.0, Age2=27.0
#   Processing pair: person017_07_36
#   ✓ Success: Age1=24.0, Age2=22.7
#   Processing pair: person017_07_38
#   ✓ Success: Age1=24.0, Age2=35.8
#   Processing pair: person017_07_42
#   ✓ Success: Age1=24.0, Age2=46.3
#   Processing pair: person017_12_26
#   ✓ Success: Age1=14.4, Age2=24.2
#   Processing pair: person017_12_29
#   ✓ Success: Age1=14.4, Age2=35.5
#   Processing pair: person017_12_32
#   ✓ Success: Age1=14.4, Age2=27.0
#   Processing pair: person017_12_36
#   ✓ Success: Age1=14.4, Age2=22.7
#   Processing pair: person017_12_38
#   ✓ Success: Age1=14.4, Age2=35.8
#   Processing pair: person017_12_42
#   ✓ Success: Age1=14.4, Age2=46.3
#   Processing pair: person017_15_26
#   ✓ Success: Age1=22.0, Age2=24.2
#   Processing pair: person017_15_29
#   ✓ Success: Age1=22.0, Age2=35.5
#   Processing pair: person017_15_32
#   ✓ Success: Age1=22.0, Age2=27.0
#   Processing pair: person017_15_36
#   ✓ Success: Age1=22.0, Age2=22.7
#   Processing pair: person017_15_38
#   ✓ Success: Age1=22.0, Age2=35.8
#   Processing pair: person017_15_42
#   ✓ Success: Age1=22.0, Age2=46.3
#   Processing pair: person017_17_29
#   ✓ Success: Age1=23.1, Age2=35.5
#   Processing pair: person017_17_32
#   ✓ Success: Age1=23.1, Age2=27.0
#   Processing pair: person017_17_36
#   ✓ Success: Age1=23.1, Age2=22.7
#   Processing pair: person017_17_38
#   ✓ Success: Age1=23.1, Age2=35.8
#   Processing pair: person017_17_42
#   ✓ Success: Age1=23.1, Age2=46.3
#   Processing pair: person017_19_32
#   ✓ Success: Age1=24.5, Age2=27.0
#   Processing pair: person017_19_36
#   ✓ Success: Age1=24.5, Age2=22.7
#   Processing pair: person017_19_38
#   ✓ Success: Age1=24.5, Age2=35.8
#   Processing pair: person017_19_42
#   ✓ Success: Age1=24.5, Age2=46.3
#   Processing pair: person017_22_36
#   ✓ Success: Age1=31.7, Age2=22.7
#   Processing pair: person017_22_38
#   ✓ Success: Age1=31.7, Age2=35.8
#   Processing pair: person017_22_42
#   ✓ Success: Age1=31.7, Age2=46.3
#   Processing pair: person017_26_38
#   ✓ Success: Age1=24.2, Age2=35.8
#   Processing pair: person017_26_42
#   ✓ Success: Age1=24.2, Age2=46.3
#   Processing pair: person017_29_42
#   ✓ Success: Age1=35.5, Age2=46.3
#
# Processing person018...
#   Processing pair: person018_06_18
#   ✓ Success: Age1=22.5, Age2=18.9
#   Processing pair: person018_06_22
#   ✓ Success: Age1=22.5, Age2=24.0
#   Processing pair: person018_06_25
#   ✓ Success: Age1=22.5, Age2=28.0
#   Processing pair: person018_06_28
#   ✓ Success: Age1=22.5, Age2=23.3
#   Processing pair: person018_06_29
#   ✓ Success: Age1=22.5, Age2=26.7
#   Processing pair: person018_06_33
#   ✓ Success: Age1=22.5, Age2=46.8
#   Processing pair: person018_06_34
#   ✓ Success: Age1=22.5, Age2=26.3
#   Processing pair: person018_06_36
#   ✓ Success: Age1=22.5, Age2=28.7
#   Processing pair: person018_11_22
#   ✓ Success: Age1=18.9, Age2=24.0
#   Processing pair: person018_11_25
#   ✓ Success: Age1=18.9, Age2=28.0
#   Processing pair: person018_11_28
#   ✓ Success: Age1=18.9, Age2=23.3
#   Processing pair: person018_11_29
#   ✓ Success: Age1=18.9, Age2=26.7
#   Processing pair: person018_11_33
#   ✓ Success: Age1=18.9, Age2=46.8
#   Processing pair: person018_11_34
#   ✓ Success: Age1=18.9, Age2=26.3
#   Processing pair: person018_11_36
#   ✓ Success: Age1=18.9, Age2=28.7
#   Processing pair: person018_16_28
#   ✓ Success: Age1=18.7, Age2=23.3
#   Processing pair: person018_16_29
#   ✓ Success: Age1=18.7, Age2=26.7
#   Processing pair: person018_16_33
#   ✓ Success: Age1=18.7, Age2=46.8
#   Processing pair: person018_16_34
#   ✓ Success: Age1=18.7, Age2=26.3
#   Processing pair: person018_16_36
#   ✓ Success: Age1=18.7, Age2=28.7
#   Processing pair: person018_18_29
#   ✓ Success: Age1=18.9, Age2=26.7
#   Processing pair: person018_18_33
#   ✓ Success: Age1=18.9, Age2=46.8
#   Processing pair: person018_18_34
#   ✓ Success: Age1=18.9, Age2=26.3
#   Processing pair: person018_18_36
#   ✓ Success: Age1=18.9, Age2=28.7
#   Processing pair: person018_22_33
#   ✓ Success: Age1=24.0, Age2=46.8
#   Processing pair: person018_22_34
#   ✓ Success: Age1=24.0, Age2=26.3
#   Processing pair: person018_22_36
#   ✓ Success: Age1=24.0, Age2=28.7
#   Processing pair: person018_25_36
#   ✓ Success: Age1=28.0, Age2=28.7
#
# Processing person019...
#   Processing pair: person019_00_12
#   ✓ Success: Age1=7.0, Age2=29.6
#   Processing pair: person019_00_15
#   ✓ Success: Age1=7.0, Age2=29.6
#   Processing pair: person019_00_18
#   ✓ Success: Age1=7.0, Age2=30.7
#   Processing pair: person019_00_23
# ...
#   Processing pair: person071_10_43
#   ✓ Success: Age1=22.1, Age2=39.8
#   Processing pair: person071_10_44
#   ✓ Success: Age1=22.1, Age2=43.7
#   Processing pair: person071_10_45
#   ✓ Success: Age1=22.1, Age2=38.8
#   Processing pair: person071_18_35
#   ✓ Success: Age1=33.5, Age2=42.7
#   Processing pair: person071_18_40
#   ✓ Success: Age1=33.5, Age2=42.7
#   Processing pair: person071_18_42
#   ✓ Success: Age1=33.5, Age2=48.0
#   Processing pair: person071_18_43
#   ✓ Success: Age1=33.5, Age2=39.8
#   Processing pair: person071_18_44
#   ✓ Success: Age1=33.5, Age2=43.7
#   Processing pair: person071_18_45
#   ✓ Success: Age1=33.5, Age2=38.8
#   Processing pair: person071_22_35
#   ✓ Success: Age1=30.0, Age2=42.7
#   Processing pair: person071_22_40
#   ✓ Success: Age1=30.0, Age2=42.7
#   Processing pair: person071_22_42
#   ✓ Success: Age1=30.0, Age2=48.0
#   Processing pair: person071_22_43
#   ✓ Success: Age1=30.0, Age2=39.8
#   Processing pair: person071_22_44
#   ✓ Success: Age1=30.0, Age2=43.7
#   Processing pair: person071_22_45
#   ✓ Success: Age1=30.0, Age2=38.8
#   Processing pair: person071_23_35
#   ✓ Success: Age1=33.1, Age2=42.7
#   Processing pair: person071_23_40
#   ✓ Success: Age1=33.1, Age2=42.7
#   Processing pair: person071_23_42
#   ✓ Success: Age1=33.1, Age2=48.0
#   Processing pair: person071_23_43
#   ✓ Success: Age1=33.1, Age2=39.8
#   Processing pair: person071_23_44
#   ✓ Success: Age1=33.1, Age2=43.7
#   Processing pair: person071_23_45
#   ✓ Success: Age1=33.1, Age2=38.8
#   Processing pair: person071_24_35
#   ✓ Success: Age1=36.5, Age2=42.7
#   Processing pair: person071_24_40
#   ✓ Success: Age1=36.5, Age2=42.7
#   Processing pair: person071_24_42
#   ✓ Success: Age1=36.5, Age2=48.0
#   Processing pair: person071_24_43
#   ✓ Success: Age1=36.5, Age2=39.8
#   Processing pair: person071_24_44
#   ✓ Success: Age1=36.5, Age2=43.7
#   Processing pair: person071_24_45
#   ✓ Success: Age1=36.5, Age2=38.8
#   Processing pair: person071_27_40
#   ✓ Success: Age1=41.7, Age2=42.7
#   Processing pair: person071_27_42
#   ✓ Success: Age1=41.7, Age2=48.0
#   Processing pair: person071_27_43
#   ✓ Success: Age1=41.7, Age2=39.8
#   Processing pair: person071_27_44
#   ✓ Success: Age1=41.7, Age2=43.7
#   Processing pair: person071_27_45
#   ✓ Success: Age1=41.7, Age2=38.8
#
# Processing person072...
#   Processing pair: person072_02_13
#   ✓ Success: Age1=5.7, Age2=23.8
#   Processing pair: person072_02_14
#   ✓ Success: Age1=5.7, Age2=22.1
#   Processing pair: person072_02_17
#   ✓ Success: Age1=5.7, Age2=20.9
#   Processing pair: person072_02_19
#   ✓ Success: Age1=5.7, Age2=26.0
#   Processing pair: person072_02_21
#   ✓ Success: Age1=5.7, Age2=26.6
#   Processing pair: person072_02_25
#   ✓ Success: Age1=5.7, Age2=30.8
#   Processing pair: person072_02_27
#   ✓ Success: Age1=5.7, Age2=45.1
#   Processing pair: person072_02_29
#   ✓ Success: Age1=5.7, Age2=23.9
#   Processing pair: person072_02_34
#   ✓ Success: Age1=5.7, Age2=28.1
#   Processing pair: person072_02_41
#   ✓ Success: Age1=5.7, Age2=39.6
#   Processing pair: person072_02_45
#   ✓ Success: Age1=5.7, Age2=41.9
#   Processing pair: person072_07_19
#   ✓ Success: Age1=10.5, Age2=26.0
#   Processing pair: person072_07_21
#   ✓ Success: Age1=10.5, Age2=26.6
#   Processing pair: person072_07_25
#   ✓ Success: Age1=10.5, Age2=30.8
#   Processing pair: person072_07_27
#   ✓ Success: Age1=10.5, Age2=45.1
#   Processing pair: person072_07_29
#   ✓ Success: Age1=10.5, Age2=23.9
#   Processing pair: person072_07_34
#   ✓ Success: Age1=10.5, Age2=28.1
#   Processing pair: person072_07_41
#   ✓ Success: Age1=10.5, Age2=39.6
#   Processing pair: person072_07_45
#   ✓ Success: Age1=10.5, Age2=41.9
#   Processing pair: person072_11_25
#   ✓ Success: Age1=14.7, Age2=30.8
#   Processing pair: person072_11_27
#   ✓ Success: Age1=14.7, Age2=45.1
#   Processing pair: person072_11_29
#   ✓ Success: Age1=14.7, Age2=23.9
#   Processing pair: person072_11_34
#   ✓ Success: Age1=14.7, Age2=28.1
#   Processing pair: person072_11_41
#   ✓ Success: Age1=14.7, Age2=39.6
#   Processing pair: person072_11_45
#   ✓ Success: Age1=14.7, Age2=41.9
#   Processing pair: person072_13_25
#   ✓ Success: Age1=23.8, Age2=30.8
#   Processing pair: person072_13_27
#   ✓ Success: Age1=23.8, Age2=45.1
#   Processing pair: person072_13_29
#   ✓ Success: Age1=23.8, Age2=23.9
#   Processing pair: person072_13_34
#   ✓ Success: Age1=23.8, Age2=28.1
#   Processing pair: person072_13_41
#   ✓ Success: Age1=23.8, Age2=39.6
#   Processing pair: person072_13_45
#   ✓ Success: Age1=23.8, Age2=41.9
#   Processing pair: person072_14_25
#   ✓ Success: Age1=22.1, Age2=30.8
#   Processing pair: person072_14_27
#   ✓ Success: Age1=22.1, Age2=45.1
#   Processing pair: person072_14_29
#   ✓ Success: Age1=22.1, Age2=23.9
#   Processing pair: person072_14_34
#   ✓ Success: Age1=22.1, Age2=28.1
#   Processing pair: person072_14_41
#   ✓ Success: Age1=22.1, Age2=39.6
#   Processing pair: person072_14_45
#   ✓ Success: Age1=22.1, Age2=41.9
#   Processing pair: person072_17_29
#   ✓ Success: Age1=20.9, Age2=23.9
#   Processing pair: person072_17_34
#   ✓ Success: Age1=20.9, Age2=28.1
#   Processing pair: person072_17_41
#   ✓ Success: Age1=20.9, Age2=39.6
#   Processing pair: person072_17_45
#   ✓ Success: Age1=20.9, Age2=41.9
#   Processing pair: person072_19_34
#   ✓ Success: Age1=26.0, Age2=28.1
#   Processing pair: person072_19_41
#   ✓ Success: Age1=26.0, Age2=39.6
#   Processing pair: person072_19_45
#   ✓ Success: Age1=26.0, Age2=41.9
#   Processing pair: person072_21_34
#   ✓ Success: Age1=26.6, Age2=28.1
#   Processing pair: person072_21_41
#   ✓ Success: Age1=26.6, Age2=39.6
#   Processing pair: person072_21_45
#   ✓ Success: Age1=26.6, Age2=41.9
#   Processing pair: person072_25_41
#   ✓ Success: Age1=30.8, Age2=39.6
#   Processing pair: person072_25_45
#   ✓ Success: Age1=30.8, Age2=41.9
#   Processing pair: person072_27_41
#   ✓ Success: Age1=45.1, Age2=39.6
#   Processing pair: person072_27_45
#   ✓ Success: Age1=45.1, Age2=41.9
#   Processing pair: person072_29_41
#   ✓ Success: Age1=23.9, Age2=39.6
#   Processing pair: person072_29_45
#   ✓ Success: Age1=23.9, Age2=41.9
#   Processing pair: person072_34_45
#   ✓ Success: Age1=28.1, Age2=41.9
#
# Processing person073...
#   Processing pair: person073_00_11
#   ✓ Success: Age1=2.9, Age2=14.7
#   Processing pair: person073_00_12
#   ✓ Success: Age1=2.9, Age2=19.8
#   Processing pair: person073_00_13
#   ✓ Success: Age1=2.9, Age2=21.4
#   Processing pair: person073_00_14
#   ✓ Success: Age1=2.9, Age2=14.3
#   Processing pair: person073_00_15
#   ✓ Success: Age1=2.9, Age2=24.5
#   Processing pair: person073_00_16
#   ✓ Success: Age1=2.9, Age2=28.3
#   Processing pair: person073_01_12
#   ✓ Success: Age1=8.2, Age2=19.8
#   Processing pair: person073_01_13
#   ✓ Success: Age1=8.2, Age2=21.4
#   Processing pair: person073_01_14
#   ✓ Success: Age1=8.2, Age2=14.3
#   Processing pair: person073_01_15
#   ✓ Success: Age1=8.2, Age2=24.5
#   Processing pair: person073_01_16
#   ✓ Success: Age1=8.2, Age2=28.3
#   Processing pair: person073_02_13
#   ✓ Success: Age1=5.8, Age2=21.4
#   Processing pair: person073_02_14
#   ✓ Success: Age1=5.8, Age2=14.3
#   Processing pair: person073_02_15
#   ✓ Success: Age1=5.8, Age2=24.5
#   Processing pair: person073_02_16
#   ✓ Success: Age1=5.8, Age2=28.3
#   Processing pair: person073_03_14
#   ✓ Success: Age1=8.3, Age2=14.3
#   Processing pair: person073_03_15
#   ✓ Success: Age1=8.3, Age2=24.5
#   Processing pair: person073_03_16
#   ✓ Success: Age1=8.3, Age2=28.3
#   Processing pair: person073_04_15
#   ✓ Success: Age1=9.9, Age2=24.5
#   Processing pair: person073_04_16
#   ✓ Success: Age1=9.9, Age2=28.3
#   Processing pair: person073_05_16
#   ✓ Success: Age1=11.4, Age2=28.3
#
# Processing person074...
#   Processing pair: person074_00_11
#   ✓ Success: Age1=5.4, Age2=10.6
#   Processing pair: person074_00_12
#   ✓ Success: Age1=5.4, Age2=17.9
#   Processing pair: person074_00_13
#   ✓ Success: Age1=5.4, Age2=23.3
#   Processing pair: person074_00_14
#   ✓ Success: Age1=5.4, Age2=22.5
#   Processing pair: person074_00_15
#   ✓ Success: Age1=5.4, Age2=19.4
#   Processing pair: person074_01_12
#   ✓ Success: Age1=3.4, Age2=17.9
#   Processing pair: person074_01_13
#   ✓ Success: Age1=3.4, Age2=23.3
#   Processing pair: person074_01_14
#   ✓ Success: Age1=3.4, Age2=22.5
#   Processing pair: person074_01_15
#   ✓ Success: Age1=3.4, Age2=19.4
#   Processing pair: person074_02_13
#   ✓ Success: Age1=6.0, Age2=23.3
#   Processing pair: person074_02_14
#   ✓ Success: Age1=6.0, Age2=22.5
#   Processing pair: person074_02_15
#   ✓ Success: Age1=6.0, Age2=19.4
#   Processing pair: person074_03_14
#   ✓ Success: Age1=9.8, Age2=22.5
#   Processing pair: person074_03_15
#   ✓ Success: Age1=9.8, Age2=19.4
#   Processing pair: person074_04_15
#   ✓ Success: Age1=5.9, Age2=19.4
#
# Processing person075...
#   Processing pair: person075_00_11
#   ✓ Success: Age1=3.1, Age2=15.2
#
# Processing person076...
#   Processing pair: person076_00_11
#   ✓ Success: Age1=1.6, Age2=13.9
#   Processing pair: person076_00_12
#   ✓ Success: Age1=1.6, Age2=14.1
#   Processing pair: person076_00_13
#   ✓ Success: Age1=1.6, Age2=13.8
#   Processing pair: person076_00_14
#   ✓ Success: Age1=1.6, Age2=20.8
#   Processing pair: person076_00_15
#   ✓ Success: Age1=1.6, Age2=12.5
#   Processing pair: person076_00_16
#   ✓ Success: Age1=1.6, Age2=15.6
#   Processing pair: person076_00_17
#   ✓ Success: Age1=1.6, Age2=20.6
#   Processing pair: person076_01_12
#   ✓ Success: Age1=5.0, Age2=14.1
#   Processing pair: person076_01_13
#   ✓ Success: Age1=5.0, Age2=13.8
#   Processing pair: person076_01_14
#   ✓ Success: Age1=5.0, Age2=20.8
#   Processing pair: person076_01_15
#   ✓ Success: Age1=5.0, Age2=12.5
#   Processing pair: person076_01_16
#   ✓ Success: Age1=5.0, Age2=15.6
#   Processing pair: person076_01_17
#   ✓ Success: Age1=5.0, Age2=20.6
#   Processing pair: person076_02_13
#   ✓ Success: Age1=6.4, Age2=13.8
#   Processing pair: person076_02_14
#   ✓ Success: Age1=6.4, Age2=20.8
#   Processing pair: person076_02_15
#   ✓ Success: Age1=6.4, Age2=12.5
#   Processing pair: person076_02_16
#   ✓ Success: Age1=6.4, Age2=15.6
#   Processing pair: person076_02_17
#   ✓ Success: Age1=6.4, Age2=20.6
#   Processing pair: person076_03_14
#   ✓ Success: Age1=6.2, Age2=20.8
#   Processing pair: person076_03_15
#   ✓ Success: Age1=6.2, Age2=12.5
#   Processing pair: person076_03_16
#   ✓ Success: Age1=6.2, Age2=15.6
#   Processing pair: person076_03_17
#   ✓ Success: Age1=6.2, Age2=20.6
#   Processing pair: person076_04_15
#   ✓ Success: Age1=8.1, Age2=12.5
#   Processing pair: person076_04_16
#   ✓ Success: Age1=8.1, Age2=15.6
#   Processing pair: person076_04_17
#   ✓ Success: Age1=8.1, Age2=20.6
#   Processing pair: person076_05_16
#   ✓ Success: Age1=12.2, Age2=15.6
#   Processing pair: person076_05_17
#   ✓ Success: Age1=12.2, Age2=20.6
#   Processing pair: person076_06_17
#   ✓ Success: Age1=12.7, Age2=20.6
#
# Processing person077...
#   Processing pair: person077_00_11
#   ✓ Success: Age1=3.3, Age2=14.6
#   Processing pair: person077_00_12
#   ✓ Success: Age1=3.3, Age2=12.9
#   Processing pair: person077_00_13
#   ✓ Success: Age1=3.3, Age2=15.2
#   Processing pair: person077_00_14
#   ✓ Success: Age1=3.3, Age2=19.4
#   Processing pair: person077_00_15
#   ✓ Success: Age1=3.3, Age2=15.8
#   Processing pair: person077_00_16
#   ✓ Success: Age1=3.3, Age2=15.3
#   Processing pair: person077_01_12
#   ✓ Success: Age1=5.1, Age2=12.9
#   Processing pair: person077_01_13
#   ✓ Success: Age1=5.1, Age2=15.2
#   Processing pair: person077_01_14
#   ✓ Success: Age1=5.1, Age2=19.4
#   Processing pair: person077_01_15
#   ✓ Success: Age1=5.1, Age2=15.8
#   Processing pair: person077_01_16
#   ✓ Success: Age1=5.1, Age2=15.3
#   Processing pair: person077_02_13
#   ✓ Success: Age1=6.4, Age2=15.2
#   Processing pair: person077_02_14
#   ✓ Success: Age1=6.4, Age2=19.4
#   Processing pair: person077_02_15
#   ✓ Success: Age1=6.4, Age2=15.8
#   Processing pair: person077_02_16
#   ✓ Success: Age1=6.4, Age2=15.3
#   Processing pair: person077_03_14
#   ✓ Success: Age1=10.2, Age2=19.4
#   Processing pair: person077_03_15
#   ✓ Success: Age1=10.2, Age2=15.8
#   Processing pair: person077_03_16
#   ✓ Success: Age1=10.2, Age2=15.3
#   Processing pair: person077_04_15
#   ✓ Success: Age1=8.5, Age2=15.8
#   Processing pair: person077_04_16
#   ✓ Success: Age1=8.5, Age2=15.3
#
# Processing person078...
#   Processing pair: person078_00_11
#   ✓ Success: Age1=9.0, Age2=12.1
#   Processing pair: person078_00_12
#   ✓ Success: Age1=9.0, Age2=13.8
#   Processing pair: person078_00_13
#   ✓ Success: Age1=9.0, Age2=16.0
#   Processing pair: person078_00_14
#   ✓ Success: Age1=9.0, Age2=21.6
#   Processing pair: person078_00_15
#   ✓ Success: Age1=9.0, Age2=20.5
#   Processing pair: person078_01_12
#   ✓ Success: Age1=5.7, Age2=13.8
#   Processing pair: person078_01_13
#   ✓ Success: Age1=5.7, Age2=16.0
#   Processing pair: person078_01_14
#   ✓ Success: Age1=5.7, Age2=21.6
#   Processing pair: person078_01_15
#   ✓ Success: Age1=5.7, Age2=20.5
#   Processing pair: person078_02_13
#   ✓ Success: Age1=9.4, Age2=16.0
#   Processing pair: person078_02_14
#   ✓ Success: Age1=9.4, Age2=21.6
#   Processing pair: person078_02_15
#   ✓ Success: Age1=9.4, Age2=20.5
#   Processing pair: person078_03_14
#   ✓ Success: Age1=7.2, Age2=21.6
#   Processing pair: person078_03_15
#   ✓ Success: Age1=7.2, Age2=20.5
#   Processing pair: person078_04_15
#   ✓ Success: Age1=12.3, Age2=20.5
#
# Processing person079...
#   Processing pair: person079_00_11
#   ✓ Success: Age1=4.9, Age2=17.7
#   Processing pair: person079_00_12
#   ✓ Success: Age1=4.9, Age2=15.4
#   Processing pair: person079_00_13
#   ✓ Success: Age1=4.9, Age2=15.7
#   Processing pair: person079_01_12
#   ✓ Success: Age1=6.0, Age2=15.4
#   Processing pair: person079_01_13
#   ✓ Success: Age1=6.0, Age2=15.7
#   Processing pair: person079_02_13
#   ✓ Success: Age1=8.0, Age2=15.7
#
# Processing person080...
#   Processing pair: person080_00_12
#   ✓ Success: Age1=5.4, Age2=12.8
#   Processing pair: person080_00_13
#   ✓ Success: Age1=5.4, Age2=13.1
#   Processing pair: person080_00_14
#   ✓ Success: Age1=5.4, Age2=12.6
#   Processing pair: person080_01_12
#   ✓ Success: Age1=5.7, Age2=12.8
#   Processing pair: person080_01_13
#   ✓ Success: Age1=5.7, Age2=13.1
#   Processing pair: person080_01_14
#   ✓ Success: Age1=5.7, Age2=12.6
#   Processing pair: person080_02_13
#   ✓ Success: Age1=5.6, Age2=13.1
#   Processing pair: person080_02_14
#   ✓ Success: Age1=5.6, Age2=12.6
#   Processing pair: person080_03_14
#   ✓ Success: Age1=9.6, Age2=12.6
#
# Processing person081...
#   Processing pair: person081_00_11
#   ✓ Success: Age1=3.2, Age2=14.2
#   Processing pair: person081_00_12
#   ✓ Success: Age1=3.2, Age2=12.9
#   Processing pair: person081_01_12
#   ✓ Success: Age1=4.9, Age2=12.9
#
# Processing person082...
#   Processing pair: person082_00_16
#   ✓ Success: Age1=27.2, Age2=17.6
#   Processing pair: person082_00_18
#   ✓ Success: Age1=27.2, Age2=23.1
#   Processing pair: person082_00_20
#   ✓ Success: Age1=27.2, Age2=25.6
#   Processing pair: person082_00_21
#   ✓ Success: Age1=27.2, Age2=15.4
#   Processing pair: person082_00_22
#   ✓ Success: Age1=27.2, Age2=20.7
#   Processing pair: person082_00_23
#   ✓ Success: Age1=27.2, Age2=22.0
#   Processing pair: person082_00_25
#   ✓ Success: Age1=27.2, Age2=21.8
#   Processing pair: person082_00_27
#   ✓ Success: Age1=27.2, Age2=20.8
#   Processing pair: person082_00_31
#   ✓ Success: Age1=27.2, Age2=18.2
#   Processing pair: person082_03_16
#   ✓ Success: Age1=9.6, Age2=17.6
#   Processing pair: person082_03_18
#   ✓ Success: Age1=9.6, Age2=23.1
#   Processing pair: person082_03_20
#   ✓ Success: Age1=9.6, Age2=25.6
#   Processing pair: person082_03_21
#   ✓ Success: Age1=9.6, Age2=15.4
#   Processing pair: person082_03_22
#   ✓ Success: Age1=9.6, Age2=20.7
#   Processing pair: person082_03_23
#   ✓ Success: Age1=9.6, Age2=22.0
#   Processing pair: person082_03_25
#   ✓ Success: Age1=9.6, Age2=21.8
#   Processing pair: person082_03_27
#   ✓ Success: Age1=9.6, Age2=20.8
#   Processing pair: person082_03_31
#   ✓ Success: Age1=9.6, Age2=18.2
#   Processing pair: person082_16_27
#   ✓ Success: Age1=17.6, Age2=20.8
#   Processing pair: person082_16_31
#   ✓ Success: Age1=17.6, Age2=18.2
#   Processing pair: person082_18_31
#   ✓ Success: Age1=23.1, Age2=18.2
#   Processing pair: person082_20_31
#   ✓ Success: Age1=25.6, Age2=18.2
#
# ============================================================
# Processing complete!
# Total pairs found: 2237
# Successfully processed: 2219
# Failed: 18
# Results saved to: fgnet_preprocessing_results.csv
# ============================================================

# %% [markdown]
# # Preprocessing of PositiveMorph

# %%
import os
import csv
import gdown
import tensorflow as tf
from facenet_pytorch import MTCNN, InceptionResnetV1
from PIL import Image
import numpy as np
import cv2
import torch
from pathlib import Path
from itertools import combinations

# Fix TensorFlow GPU memory issues
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✓ GPU memory growth enabled for {len(gpus)} GPU(s)")
    except RuntimeError as e:
        print(f"GPU configuration error: {e}")
else:
    print("Running on CPU")

# -----------------------------
# 1. Load Models
# -----------------------------
print("Loading models...")
output_path = "resnet50_age_model.keras"
if not os.path.exists(output_path):
    print("Downloading age model...")
    file_id = "1xyGYBYRQwjBpPreZmvv_enQ3Z92wHNSx"
    download_url = f"https://drive.google.com/uc?id={file_id}"
    gdown.download(download_url, output_path, quiet=False)
else:
    print("Age model already exists, skipping download...")

age_model = tf.keras.models.load_model(output_path)
mtcnn = MTCNN()
facenet = InceptionResnetV1(pretrained='vggface2').eval()
print("✓ All models loaded!")

# -----------------------------
# 2. Helper Functions
# -----------------------------
def align_face(img_cv, landmark, output_size=(224, 224)):
    left_eye, right_eye, nose = landmark[0], landmark[1], landmark[2]
    eyes_center = ((left_eye[0] + right_eye[0]) / 2,
                   (left_eye[1] + right_eye[1]) / 2)
    dy, dx = right_eye[1] - left_eye[1], right_eye[0] - left_eye[0]
    angle = np.degrees(np.arctan2(dy, dx))
    desired_eye_distance = output_size[0] * 0.35
    dist = np.sqrt(dx**2 + dy**2)
    scale = desired_eye_distance / dist
    M = cv2.getRotationMatrix2D(eyes_center, angle, scale)
    M[0, 2] += (output_size[0] * 0.5 - eyes_center[0])
    M[1, 2] += (output_size[1] * 0.4 - eyes_center[1])
    aligned_face = cv2.warpAffine(img_cv, M, output_size, flags=cv2.INTER_CUBIC)
    return aligned_face

def preprocess_for_age(face_img):
    from tensorflow.keras.applications.resnet50 import preprocess_input
    x = cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return x

def preprocess_for_facenet(face_img):
    face_resized = cv2.resize(face_img, (160, 160))
    face_rgb = cv2.cvtColor(face_resized, cv2.COLOR_BGR2RGB)
    face_normalized = (face_rgb - 127.5) / 128.0
    face_tensor = torch.FloatTensor(face_normalized).permute(2, 0, 1).unsqueeze(0)
    return face_tensor

def process_image(img_path):
    try:
        img = Image.open(img_path).convert('RGB')
        img_cv = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
        boxes, probs, landmarks = mtcnn.detect(img, landmarks=True)
        if boxes is None or len(boxes) == 0:
            print(f"  ⚠ No face detected in {img_path}")
            return None, None
        aligned_face = align_face(img_cv, landmarks[0], output_size=(224, 224))
        if aligned_face is None or aligned_face.shape != (224, 224, 3):
            print(f"  ⚠ Invalid aligned face shape in {img_path}")
            return None, None
        age_input = preprocess_for_age(aligned_face)
        if age_input.shape != (1, 224, 224, 3):
            print(f"  ⚠ Invalid age input shape: {age_input.shape}")
            return None, None
        age = age_model.predict(age_input, verbose=0)[0][0]
        face_tensor = preprocess_for_facenet(aligned_face)
        with torch.no_grad():
            embedding = facenet(face_tensor).numpy().flatten()
        return float(age), embedding.tolist()
    except Exception as e:
        print(f"  ✗ Error processing {img_path}: {str(e)}")
        import traceback
        traceback.print_exc()
        return None, None

def process_dataset(dataset_root, output_csv):
    dataset_path = Path(dataset_root)
    with open(output_csv, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['image_path1', 'image_path2', 'age1', 'age2', 'embedding1', 'embedding2'])
        person_folders = sorted([f for f in dataset_path.iterdir() if f.is_dir()])
        print(f"\nFound {len(person_folders)} person folders")
        print("="*60)
        total_pairs = 0
        successful_pairs = 0
        for person_folder in person_folders:
            person_name = person_folder.name
            print(f"\nProcessing {person_name}...")
            image_files = sorted([f for f in person_folder.iterdir()
                                  if f.suffix.lower() in ['.jpg', '.jpeg', '.png']])
            if len(image_files) < 2:
                print(f"  ⚠ Found only {len(image_files)} image(s). Skipping.")
                continue
            pairs = list(combinations(image_files, 2))
            print(f"  Found {len(image_files)} images → {len(pairs)} pairs")
            for idx, (img_file1, img_file2) in enumerate(pairs, 1):
                total_pairs += 1
                img_path1 = str(img_file1)
                img_path2 = str(img_file2)
                print(f"  Pair {idx}/{len(pairs)}: {img_file1.name} + {img_file2.name}")
                age1, embedding1 = process_image(img_path1)
                age2, embedding2 = process_image(img_path2)
                if age1 is not None and age2 is not None:
                    writer.writerow([img_path1, img_path2, age1, age2, embedding1, embedding2])
                    successful_pairs += 1
                    print(f"    ✓ Success: Age1={age1:.1f}, Age2={age2:.1f}")
                else:
                    print(f"    ✗ Failed to process pair")
        print("\n" + "="*60)
        print(f"Processing complete!")
        print(f"Total pairs found: {total_pairs}")
        print(f"Successfully processed: {successful_pairs}")
        print(f"Failed: {total_pairs - successful_pairs}")
        print(f"Results saved to: {output_csv}")
        print("="*60)

# -----------------------------
# 3. Main Execution
# -----------------------------
if __name__ == "__main__":
    dataset_root = "/content/MLP_dataset/Positive_Morph"
    output_csv = "morph_preprocessing_results.csv"
    process_dataset(dataset_root, output_csv)
# Out:
# Streaming output truncated to the last 5000 lines.
#     ✓ Success: Age1=30.3, Age2=28.1
#   Pair 40/153: 119392_13M32.JPG + 119392_24M33.JPG
#     ✓ Success: Age1=28.5, Age2=32.7
#   Pair 53/55: 120381_6M35.JPG + 120381_7M35.JPG
#     ✓ Success: Age1=27.4, Age2=29.5
#   Pair 54/55: 120381_6M35.JPG + 120381_8M35.JPG
#     ✓ Success: Age1=27.4, Age2=32.7
#   Pair 55/55: 120381_7M35.JPG + 120381_8M35.JPG
#     ✓ Success: Age1=29.5, Age2=32.7
#
# Processing 121526_31-36...
#   Found 3 images → 3 pairs
#   Pair 1/3: 121526_03M36.JPG + 121526_0M31.JPG
#     ✓ Success: Age1=34.5, Age2=23.1
#   Pair 2/3: 121526_03M36.JPG + 121526_2M32.JPG
#     ✓ Success: Age1=34.5, Age2=28.8
#   Pair 3/3: 121526_0M31.JPG + 121526_2M32.JPG
#     ✓ Success: Age1=23.1, Age2=28.8
#
# Processing 122108_25-37...
#   Found 4 images → 6 pairs
#   Pair 1/6: 122108_04M37.JPG + 122108_05M37.JPG
#     ✓ Success: Age1=35.1, Age2=35.9
#   Pair 2/6: 122108_04M37.JPG + 122108_0M34.JPG
#     ✓ Success: Age1=35.1, Age2=35.1
#   Pair 3/6: 122108_04M37.JPG + 122108_1M25.JPG
#     ✓ Success: Age1=35.1, Age2=36.6
#   Pair 4/6: 122108_05M37.JPG + 122108_0M34.JPG
#     ✓ Success: Age1=35.9, Age2=35.1
#   Pair 5/6: 122108_05M37.JPG + 122108_1M25.JPG
#     ✓ Success: Age1=35.9, Age2=36.6
#   Pair 6/6: 122108_0M34.JPG + 122108_1M25.JPG
#     ✓ Success: Age1=35.1, Age2=36.6
#
# Processing 122763_24-33...
#   Found 2 images → 1 pairs
#   Pair 1/1: 122763_0M33.JPG + 122763_1M24.JPG
#     ✓ Success: Age1=28.2, Age2=35.8
#
# Processing 125724_32-37...
#   Found 6 images → 15 pairs
#   Pair 1/15: 125724_04M35.JPG + 125724_05M35.JPG
#     ✓ Success: Age1=39.5, Age2=41.0
#   Pair 2/15: 125724_04M35.JPG + 125724_06M35.JPG
#     ✓ Success: Age1=39.5, Age2=40.0
#   Pair 3/15: 125724_04M35.JPG + 125724_08M36.JPG
#     ✓ Success: Age1=39.5, Age2=39.2
#   Pair 4/15: 125724_04M35.JPG + 125724_0M32.JPG
#     ✓ Success: Age1=39.5, Age2=34.3
#   Pair 5/15: 125724_04M35.JPG + 125724_10M37.JPG
#     ✓ Success: Age1=39.5, Age2=35.0
#   Pair 6/15: 125724_05M35.JPG + 125724_06M35.JPG
#     ✓ Success: Age1=41.0, Age2=40.0
#   Pair 7/15: 125724_05M35.JPG + 125724_08M36.JPG
#     ✓ Success: Age1=41.0, Age2=39.2
#   Pair 8/15: 125724_05M35.JPG + 125724_0M32.JPG
#     ✓ Success: Age1=41.0, Age2=34.3
#   Pair 9/15: 125724_05M35.JPG + 125724_10M37.JPG
#     ✓ Success: Age1=41.0, Age2=35.0
#   Pair 10/15: 125724_06M35.JPG + 125724_08M36.JPG
#     ✓ Success: Age1=40.0, Age2=39.2
#   Pair 11/15: 125724_06M35.JPG + 125724_0M32.JPG
#     ✓ Success: Age1=40.8, Age2=39.2
#   Pair 2/3: 127267_00M37.JPG + 127267_02M44.JPG
#     ✓ Success: Age1=40.8, Age2=33.2
#   Pair 3/3: 127267_01M38.JPG + 127267_02M44.JPG
#     ✓ Success: Age1=39.2, Age2=33.2
#
# Processing 12740_27-35...
#   Found 2 images → 1 pairs
#   Pair 1/1: 12740_00M35.JPG + 12740_03M27.JPG
#     ✓ Success: Age1=24.7, Age2=29.6
#
# Processing 127870_33-38...
#   Found 3 images → 3 pairs
#   Pair 1/3: 127870_02M38.JPG + 127870_0M33.JPG
#     ✓ Success: Age1=28.2, Age2=28.8
#   Pair 2/3: 127870_02M38.JPG + 127870_1M34.JPG
#     ✓ Success: Age1=28.2, Age2=29.0
#   Pair 3/3: 127870_0M33.JPG + 127870_1M34.JPG
#     ✓ Success: Age1=28.8, Age2=29.0
#
# Processing 128931_34-39...
#   Found 8 images → 28 pairs
#   Pair 1/28: 128931_07M39.JPG + 128931_0M34.JPG
#     ✓ Success: Age1=33.6, Age2=30.0
#   Pair 2/28: 128931_07M39.JPG + 128931_1M35.JPG
#     ✓ Success: Age1=33.6, Age2=28.7
#   Pair 3/28: 128931_07M39.JPG + 128931_2M36.JPG
#     ✓ Success: Age1=33.6, Age2=30.7
#   Pair 4/28: 128931_07M39.JPG + 128931_3M36.JPG
#     ✓ Success: Age1=33.6, Age2=30.9
#   Pair 5/28: 128931_07M39.JPG + 128931_4M36.JPG
#     ✓ Success: Age1=33.6, Age2=31.3
#   Pair 6/28: 128931_07M39.JPG + 128931_5M36.JPG
#     ✓ Success: Age1=33.6, Age2=26.0
#   Pair 7/28: 128931_07M39.JPG + 128931_6M37.JPG
#     ✓ Success: Age1=33.6, Age2=25.3
#   Pair 8/28: 128931_0M34.JPG + 128931_1M35.JPG
#     ✓ Success: Age1=30.0, Age2=28.7
#   Pair 9/28: 128931_0M34.JPG + 128931_2M36.JPG
#     ✓ Success: Age1=30.0, Age2=30.7
#   Pair 10/28: 128931_0M34.JPG + 128931_3M36.JPG
#     ✓ Success: Age1=30.0, Age2=30.9
#   Pair 11/28: 128931_0M34.JPG + 128931_4M36.JPG
#     ✓ Success: Age1=30.0, Age2=31.3
#   Pair 12/28: 128931_0M34.JPG + 128931_5M36.JPG
#     ✓ Success: Age1=30.0, Age2=26.0
#   Pair 13/28: 128931_0M34.JPG + 128931_6M37.JPG
#     ✓ Success: Age1=30.0, Age2=25.3
#   Pair 14/28: 128931_1M35.JPG + 128931_2M36.JPG
#     ✓ Success: Age1=28.7, Age2=30.7
#   Pair 15/28: 128931_1M35.JPG + 128931_3M36.JPG
#     ✓ Success: Age1=28.7, Age2=30.9
#   Pair 16/28: 128931_1M35.JPG + 128931_4M36.JPG
#     ✓ Success: Age1=28.7, Age2=31.3
#   Pair 17/28: 128931_1M35.JPG + 128931_5M36.JPG
#     ✓ Success: Age1=28.7, Age2=26.0
#   Pair 18/28: 128931_1M35.JPG + 128931_6M37.JPG
#     ✓ Success: Age1=28.7, Age2=25.3
#   Pair 19/28: 128931_2M36.JPG + 128931_3M36.JPG
#     ✓ Success: Age1=30.7, Age2=30.9
#   Pair 20/28: 128931_2M36.JPG + 128931_4M36.JPG
#     ✓ Success: Age1=30.7, Age2=31.3
#   Pair 21/28: 128931_2M36.JPG + 128931_5M36.JPG
#     ✓ Success: Age1=30.7, Age2=26.0
#   Pair 22/28: 128931_2M36.JPG + 128931_6M37.JPG
#     ✓ Success: Age1=30.7, Age2=25.3
#   Pair 23/28: 128931_3M36.JPG + 128931_4M36.JPG
#     ✓ Success: Age1=30.9, Age2=31.3
#   Pair 24/28: 128931_3M36.JPG + 128931_5M36.JPG
#     ✓ Success: Age1=30.9, Age2=26.0
#   Pair 25/28: 128931_3M36.JPG + 128931_6M37.JPG
#     ✓ Success: Age1=30.9, Age2=25.3
#   Pair 26/28: 128931_4M36.JPG + 128931_5M36.JPG
#     ✓ Success: Age1=31.3, Age2=26.0
#   Pair 27/28: 128931_4M36.JPG + 128931_6M37.JPG
#     ✓ Success: Age1=31.3, Age2=25.3
#   Pair 28/28: 128931_5M36.JPG + 128931_6M37.JPG
#     ✓ Success: Age1=26.0, Age2=25.3
#
# Processing 129153_34-39...
#   Found 7 images → 21 pairs
#   Pair 1/21: 129153_06M38.JPG + 129153_07M38.JPG
#     ✓ Success: Age1=31.7, Age2=34.5
#   Pair 2/21: 129153_06M38.JPG + 129153_08M39.JPG
#     ✓ Success: Age1=31.7, Age2=28.4
#   Pair 3/21: 129153_06M38.JPG + 129153_0M34.JPG
#     ✓ Success: Age1=31.7, Age2=34.3
#   Pair 4/21: 129153_06M38.JPG + 129153_3M36.JPG
#     ✓ Success: Age1=31.7, Age2=38.7
#   Pair 5/21: 129153_06M38.JPG + 129153_4M36.JPG
#     ✓ Success: Age1=31.7, Age2=37.7
#   Pair 6/21: 129153_06M38.JPG + 129153_5M36.JPG
#     ✓ Success: Age1=31.7, Age2=33.0
#   Pair 7/21: 129153_07M38.JPG + 129153_08M39.JPG
#     ✓ Success: Age1=34.5, Age2=28.4
#   Pair 8/21: 129153_07M38.JPG + 129153_0M34.JPG
#     ✓ Success: Age1=34.5, Age2=34.3
#   Pair 9/21: 129153_07M38.JPG + 129153_3M36.JPG
#     ✓ Success: Age1=34.5, Age2=38.7
#   Pair 10/21: 129153_07M38.JPG + 129153_4M36.JPG
#     ✓ Success: Age1=34.5, Age2=37.7
#   Pair 11/21: 129153_07M38.JPG + 129153_5M36.JPG
#     ✓ Success: Age1=34.5, Age2=33.0
#   Pair 12/21: 129153_08M39.JPG + 129153_0M34.JPG
#     ✓ Success: Age1=28.4, Age2=34.3
#   Pair 13/21: 129153_08M39.JPG + 129153_3M36.JPG
#     ✓ Success: Age1=28.4, Age2=38.7
#   Pair 14/21: 129153_08M39.JPG + 129153_4M36.JPG
#     ✓ Success: Age1=28.4, Age2=37.7
#   Pair 15/21: 129153_08M39.JPG + 129153_5M36.JPG
#     ✓ Success: Age1=28.4, Age2=33.0
#   Pair 16/21: 129153_0M34.JPG + 129153_3M36.JPG
#     ✓ Success: Age1=34.3, Age2=38.7
#   Pair 17/21: 129153_0M34.JPG + 129153_4M36.JPG
#     ✓ Success: Age1=34.3, Age2=37.7
#   Pair 18/21: 129153_0M34.JPG + 129153_5M36.JPG
#     ✓ Success: Age1=34.3, Age2=33.0
#   Pair 19/21: 129153_3M36.JPG + 129153_4M36.JPG
#     ✓ Success: Age1=38.7, Age2=37.7
#   Pair 20/21: 129153_3M36.JPG + 129153_5M36.JPG
#     ✓ Success: Age1=38.7, Age2=33.0
#   Pair 21/21: 129153_4M36.JPG + 129153_5M36.JPG
#     ✓ Success: Age1=37.7, Age2=33.0
#
# Processing 129358_34-44...
#   Found 3 images → 3 pairs
#   Pair 1/3: 129358_02M36.JPG + 129358_0M34.JPG
# ...
#   Pair 6/10: 331076_02M17.JPG + 331076_06M24.JPG
#     ✓ Success: Age1=23.9, Age2=21.2
#   Pair 7/10: 331076_02M17.JPG + 331076_07M18.JPG
#     ✓ Success: Age1=23.9, Age2=22.5
#   Pair 8/10: 331076_05M18.JPG + 331076_06M24.JPG
#     ✓ Success: Age1=18.9, Age2=21.2
#   Pair 9/10: 331076_05M18.JPG + 331076_07M18.JPG
#     ✓ Success: Age1=18.9, Age2=22.5
#   Pair 10/10: 331076_06M24.JPG + 331076_07M18.JPG
#     ✓ Success: Age1=21.2, Age2=22.5
#
# Processing 33594_39-50...
#   Found 2 images → 1 pairs
#   Pair 1/1: 33594_2M39.JPG + 33594_5M50.JPG
#     ✓ Success: Age1=36.6, Age2=36.8
#
# Processing 33865_31-36...
#   Found 2 images → 1 pairs
#   Pair 1/1: 33865_05M36.JPG + 33865_1M31.JPG
#     ✓ Success: Age1=31.2, Age2=30.8
#
# Processing 34210_38-48...
#   Found 9 images → 36 pairs
#   Pair 1/36: 34210_13M39.JPG + 34210_16M39.JPG
#     ✓ Success: Age1=30.0, Age2=29.2
#   Pair 2/36: 34210_13M39.JPG + 34210_21M40.JPG
#     ✓ Success: Age1=30.0, Age2=31.7
#   Pair 3/36: 34210_13M39.JPG + 34210_22M40.JPG
#     ✓ Success: Age1=30.0, Age2=30.0
#   Pair 4/36: 34210_13M39.JPG + 34210_24M40.JPG
#     ✓ Success: Age1=30.0, Age2=34.8
#   Pair 5/36: 34210_13M39.JPG + 34210_25M40.JPG
#     ✓ Success: Age1=30.0, Age2=34.3
#   Pair 6/36: 34210_13M39.JPG + 34210_27M41.JPG
#     ✓ Success: Age1=30.0, Age2=34.3
#   Pair 7/36: 34210_13M39.JPG + 34210_5M48.JPG
#     ✓ Success: Age1=30.0, Age2=27.7
#   Pair 8/36: 34210_13M39.JPG + 34210_8M38.JPG
#     ✓ Success: Age1=30.0, Age2=35.1
#   Pair 9/36: 34210_16M39.JPG + 34210_21M40.JPG
#     ✓ Success: Age1=29.2, Age2=31.7
#   Pair 10/36: 34210_16M39.JPG + 34210_22M40.JPG
#     ✓ Success: Age1=29.2, Age2=30.0
#   Pair 11/36: 34210_16M39.JPG + 34210_24M40.JPG
#     ✓ Success: Age1=29.2, Age2=34.8
#     ✓ Success: Age1=59.2, Age2=47.1
#   Pair 11/15: 40589_03M50.JPG + 40589_20M51.JPG
#     ✓ Success: Age1=59.2, Age2=49.4
#   Pair 12/15: 40589_03M50.JPG + 40589_24M51.JPG
#     ✓ Success: Age1=59.2, Age2=46.4
#   Pair 13/15: 40589_19M51.JPG + 40589_20M51.JPG
#     ✓ Success: Age1=47.1, Age2=49.4
#   Pair 14/15: 40589_19M51.JPG + 40589_24M51.JPG
#     ✓ Success: Age1=47.1, Age2=46.4
#   Pair 15/15: 40589_20M51.JPG + 40589_24M51.JPG
#     ✓ Success: Age1=49.4, Age2=46.4
#
# Processing 4128_19-36...
#   Found 2 images → 1 pairs
#   Pair 1/1: 4128_00M19.JPG + 4128_00M36.JPG
#     ✓ Success: Age1=14.7, Age2=30.9
#
# Processing 41803_17-27...
#   Found 2 images → 1 pairs
#   Pair 1/1: 41803_01M17.JPG + 41803_01M27.JPG
#     ✓ Success: Age1=18.7, Age2=29.6
#
# Processing 49452_24-53...
#   Found 4 images → 6 pairs
#   Pair 1/6: 49452_02M53.JPG + 49452_05M24.JPG
#     ✓ Success: Age1=22.9, Age2=24.7
#   Pair 2/6: 49452_02M53.JPG + 49452_06M24.JPG
#     ✓ Success: Age1=22.9, Age2=26.0
#   Pair 3/6: 49452_02M53.JPG + 49452_07M24.JPG
#     ✓ Success: Age1=22.9, Age2=22.8
#   Pair 4/6: 49452_05M24.JPG + 49452_06M24.JPG
#     ✓ Success: Age1=24.7, Age2=26.0
#   Pair 5/6: 49452_05M24.JPG + 49452_07M24.JPG
#     ✓ Success: Age1=24.7, Age2=22.8
#   Pair 6/6: 49452_06M24.JPG + 49452_07M24.JPG
#     ✓ Success: Age1=26.0, Age2=22.8
#
# Processing 5127_17-26...
#   Found 3 images → 3 pairs
#   Pair 1/3: 5127_00M17.JPG + 5127_00M25.JPG
#     ✓ Success: Age1=24.1, Age2=23.7
#   Pair 2/3: 5127_00M17.JPG + 5127_03M26.JPG
#     ✓ Success: Age1=24.1, Age2=25.2
#   Pair 3/3: 5127_00M25.JPG + 5127_03M26.JPG
#     ✓ Success: Age1=23.7, Age2=25.2
#
# Processing 52117_24-42...
#   Found 3 images → 3 pairs
#   Pair 1/3: 52117_01F42.JPG + 52117_03M24.JPG
#     ✓ Success: Age1=43.4, Age2=22.7
#   Pair 2/3: 52117_01F42.JPG + 52117_05M25.JPG
#     ✓ Success: Age1=43.4, Age2=23.0
#   Pair 3/3: 52117_03M24.JPG + 52117_05M25.JPG
#     ✓ Success: Age1=22.7, Age2=23.0
#
# Processing 5450_28-36...
#   Found 2 images → 1 pairs
#   Pair 1/1: 5450_1M36.JPG + 5450_3M28.JPG
#     ✓ Success: Age1=27.8, Age2=29.5
#
# Processing 547_28-53...
#   Found 2 images → 1 pairs
#   Pair 1/1: 547_00M28.JPG + 547_0M53.JPG
#     ✓ Success: Age1=25.7, Age2=44.3
#
# Processing 5740_37-48...
#   Found 2 images → 1 pairs
#   Pair 1/1: 5740_1M37.JPG + 5740_3M48.JPG
#     ✓ Success: Age1=33.1, Age2=38.0
#
# Processing 5836_16-36...
#   Found 3 images → 3 pairs
#   Pair 1/3: 5836_00M16.JPG + 5836_01M17.JPG
#     ✓ Success: Age1=19.1, Age2=13.8
#   Pair 2/3: 5836_00M16.JPG + 5836_4M36.JPG
#     ✓ Success: Age1=19.1, Age2=35.5
#   Pair 3/3: 5836_01M17.JPG + 5836_4M36.JPG
#     ✓ Success: Age1=13.8, Age2=35.5
#
# Processing 5850_17-36...
#   Found 3 images → 3 pairs
#   Pair 1/3: 5850_00F17.JPG + 5850_02F18.JPG
#     ✓ Success: Age1=14.6, Age2=21.5
#   Pair 2/3: 5850_00F17.JPG + 5850_03M36.JPG
#     ✓ Success: Age1=14.6, Age2=37.6
#   Pair 3/3: 5850_02F18.JPG + 5850_03M36.JPG
#     ✓ Success: Age1=21.5, Age2=37.6
#
# Processing 6227_38-44...
#   Found 2 images → 1 pairs
#   Pair 1/1: 6227_06M44.JPG + 6227_2M38.JPG
#     ✓ Success: Age1=31.6, Age2=31.1
#
# Processing 68175_28-36...
#   Found 5 images → 10 pairs
#   Pair 1/10: 68175_00M35.JPG + 68175_01M35.JPG
#     ✓ Success: Age1=29.6, Age2=29.0
#   Pair 2/10: 68175_00M35.JPG + 68175_02M28.JPG
#     ✓ Success: Age1=29.6, Age2=25.4
#   Pair 3/10: 68175_00M35.JPG + 68175_03M36.JPG
#     ✓ Success: Age1=29.6, Age2=28.0
#   Pair 4/10: 68175_00M35.JPG + 68175_04M36.JPG
#     ✓ Success: Age1=29.6, Age2=26.8
#   Pair 5/10: 68175_01M35.JPG + 68175_02M28.JPG
#     ✓ Success: Age1=29.0, Age2=25.4
#   Pair 6/10: 68175_01M35.JPG + 68175_03M36.JPG
#     ✓ Success: Age1=29.0, Age2=28.0
#   Pair 7/10: 68175_01M35.JPG + 68175_04M36.JPG
#     ✓ Success: Age1=29.0, Age2=26.8
#   Pair 8/10: 68175_02M28.JPG + 68175_03M36.JPG
#     ✓ Success: Age1=25.4, Age2=28.0
#   Pair 9/10: 68175_02M28.JPG + 68175_04M36.JPG
#     ✓ Success: Age1=25.4, Age2=26.8
#   Pair 10/10: 68175_03M36.JPG + 68175_04M36.JPG
#     ✓ Success: Age1=28.0, Age2=26.8
#
# Processing 68633_47-53...
#   Found 4 images → 6 pairs
#   Pair 1/6: 68633_00M47.JPG + 68633_01M52.JPG
#     ✓ Success: Age1=45.2, Age2=54.2
#   Pair 2/6: 68633_00M47.JPG + 68633_04M48.JPG
#     ✓ Success: Age1=45.2, Age2=40.6
#   Pair 3/6: 68633_00M47.JPG + 68633_05M53.JPG
#     ✓ Success: Age1=45.2, Age2=46.6
#   Pair 4/6: 68633_01M52.JPG + 68633_04M48.JPG
#     ✓ Success: Age1=54.2, Age2=40.6
#   Pair 5/6: 68633_01M52.JPG + 68633_05M53.JPG
#     ✓ Success: Age1=54.2, Age2=46.6
#   Pair 6/6: 68633_04M48.JPG + 68633_05M53.JPG
#     ✓ Success: Age1=40.6, Age2=46.6
#
# Processing 73458_45-53...
#   Found 3 images → 3 pairs
#   Pair 1/3: 73458_00M53.JPG + 73458_03M53.JPG
#     ✓ Success: Age1=39.8, Age2=25.6
#   Pair 2/3: 73458_00M53.JPG + 73458_19M45.JPG
#     ✓ Success: Age1=39.8, Age2=29.6
#   Pair 3/3: 73458_03M53.JPG + 73458_19M45.JPG
#     ✓ Success: Age1=25.6, Age2=29.6
#
# Processing 74427_25-30...
#   Found 2 images → 1 pairs
#   Pair 1/1: 74427_01M25.JPG + 74427_06M30.JPG
#     ✓ Success: Age1=37.7, Age2=25.3
#
# Processing 7541_21-40...
#   Found 2 images → 1 pairs
#   Pair 1/1: 7541_01M21.JPG + 7541_03M40.JPG
#     ✓ Success: Age1=19.1, Age2=43.7
#
# Processing 76587_37-47...
#   Found 2 images → 1 pairs
#   Pair 1/1: 76587_00F37.JPG + 76587_03F47.JPG
#     ✓ Success: Age1=29.4, Age2=27.8
#
# Processing 77434_23-30...
#   Found 3 images → 3 pairs
#   Pair 1/3: 77434_01M23.JPG + 77434_01M30.JPG
#     ✓ Success: Age1=20.6, Age2=29.5
#   Pair 2/3: 77434_01M23.JPG + 77434_02M23.JPG
#     ✓ Success: Age1=20.6, Age2=23.0
#   Pair 3/3: 77434_01M30.JPG + 77434_02M23.JPG
#     ✓ Success: Age1=29.5, Age2=23.0
#
# Processing 8230_24-34...
#   Found 2 images → 1 pairs
#   Pair 1/1: 8230_00M24.JPG + 8230_0M34.JPG
#     ✓ Success: Age1=29.4, Age2=25.9
#
# Processing 82424_20-30...
#   Found 3 images → 3 pairs
#   Pair 1/3: 82424_00M20.JPG + 82424_00M30.JPG
#     ✓ Success: Age1=21.7, Age2=32.0
#   Pair 2/3: 82424_00M20.JPG + 82424_06M22.JPG
#     ✓ Success: Age1=21.7, Age2=22.4
#   Pair 3/3: 82424_00M30.JPG + 82424_06M22.JPG
#     ✓ Success: Age1=32.0, Age2=22.4
#
# Processing 8878_52-57...
#   Found 3 images → 3 pairs
#   Pair 1/3: 8878_09M57.JPG + 8878_1M52.JPG
#     ✓ Success: Age1=39.6, Age2=34.2
#   Pair 2/3: 8878_09M57.JPG + 8878_4M53.JPG
#     ✓ Success: Age1=39.6, Age2=39.7
#   Pair 3/3: 8878_1M52.JPG + 8878_4M53.JPG
#     ✓ Success: Age1=34.2, Age2=39.7
#
# Processing 90173_28-35...
#   Found 4 images → 6 pairs
#   Pair 1/6: 90173_02M35.JPG + 90173_04M28.JPG
#     ✓ Success: Age1=23.8, Age2=24.9
#   Pair 2/6: 90173_02M35.JPG + 90173_10M29.JPG
#     ✓ Success: Age1=23.8, Age2=22.0
#   Pair 3/6: 90173_02M35.JPG + 90173_11M29.JPG
#     ✓ Success: Age1=23.8, Age2=22.2
#   Pair 4/6: 90173_04M28.JPG + 90173_10M29.JPG
#     ✓ Success: Age1=24.9, Age2=22.0
#   Pair 5/6: 90173_04M28.JPG + 90173_11M29.JPG
#     ✓ Success: Age1=24.9, Age2=22.2
#   Pair 6/6: 90173_10M29.JPG + 90173_11M29.JPG
#     ✓ Success: Age1=22.0, Age2=22.2
#
# Processing 9089_17-43...
#   Found 2 images → 1 pairs
#   Pair 1/1: 9089_00M17.JPG + 9089_0F43.JPG
#     ✓ Success: Age1=16.7, Age2=25.9
#
# Processing 93294_28-33...
#   Found 2 images → 1 pairs
#   Pair 1/1: 93294_00M28.JPG + 93294_03M33.JPG
#     ✓ Success: Age1=25.2, Age2=28.3
#
# Processing 94261_28-39...
#   Found 3 images → 3 pairs
#   Pair 1/3: 94261_02M28.JPG + 94261_09M39.JPG
#     ✓ Success: Age1=24.3, Age2=35.0
#   Pair 2/3: 94261_02M28.JPG + 94261_13M39.JPG
#     ✓ Success: Age1=24.3, Age2=33.2
#   Pair 3/3: 94261_09M39.JPG + 94261_13M39.JPG
#     ✓ Success: Age1=35.0, Age2=33.2
#
# Processing 94658_23-34...
#   Found 3 images → 3 pairs
#   Pair 1/3: 94658_00F23.JPG + 94658_01M34.JPG
#     ✓ Success: Age1=22.2, Age2=25.3
#   Pair 2/3: 94658_00F23.JPG + 94658_03F25.JPG
#     ✓ Success: Age1=22.2, Age2=24.3
#   Pair 3/3: 94658_01M34.JPG + 94658_03F25.JPG
#     ✓ Success: Age1=25.3, Age2=24.3
#
# Processing 94852_19-29...
#   Found 2 images → 1 pairs
#   Pair 1/1: 94852_03M29.JPG + 94852_04M19.JPG
#     ✓ Success: Age1=27.3, Age2=25.4
#
# Processing 95104_33-49...
#   Found 3 images → 3 pairs
#   Pair 1/3: 95104_00F39.JPG + 95104_02F33.JPG
#     ✓ Success: Age1=34.3, Age2=20.8
#   Pair 2/3: 95104_00F39.JPG + 95104_02F49.JPG
#     ✓ Success: Age1=34.3, Age2=42.5
#   Pair 3/3: 95104_02F33.JPG + 95104_02F49.JPG
#     ✓ Success: Age1=20.8, Age2=42.5
#
# Processing 97729_20-31...
#   Found 3 images → 3 pairs
#   Pair 1/3: 97729_00M28.JPG + 97729_03M20.JPG
#     ✓ Success: Age1=30.7, Age2=25.6
#   Pair 2/3: 97729_00M28.JPG + 97729_05M31.JPG
#     ✓ Success: Age1=30.7, Age2=27.2
#   Pair 3/3: 97729_03M20.JPG + 97729_05M31.JPG
#     ✓ Success: Age1=25.6, Age2=27.2
#
# Processing 98025_22-27...
#   Found 2 images → 1 pairs
#   Pair 1/1: 98025_01M22.JPG + 98025_04M27.JPG
#     ✓ Success: Age1=21.7, Age2=30.4
#
# Processing 9893_50-58...
#   Found 6 images → 15 pairs
#   Pair 1/15: 9893_12M55.JPG + 9893_23M57.JPG
#     ✓ Success: Age1=53.2, Age2=50.8
#   Pair 2/15: 9893_12M55.JPG + 9893_26M57.JPG
#     ✓ Success: Age1=53.2, Age2=52.1
#   Pair 3/15: 9893_12M55.JPG + 9893_30M58.JPG
#     ✓ Success: Age1=53.2, Age2=49.8
#   Pair 4/15: 9893_12M55.JPG + 9893_31M50.JPG
#     ✓ Success: Age1=53.2, Age2=46.2
#   Pair 5/15: 9893_12M55.JPG + 9893_35M50.JPG
#     ✓ Success: Age1=53.2, Age2=57.1
#   Pair 6/15: 9893_23M57.JPG + 9893_26M57.JPG
#     ✓ Success: Age1=50.8, Age2=52.1
#   Pair 7/15: 9893_23M57.JPG + 9893_30M58.JPG
#     ✓ Success: Age1=50.8, Age2=49.8
#   Pair 8/15: 9893_23M57.JPG + 9893_31M50.JPG
#     ✓ Success: Age1=50.8, Age2=46.2
#   Pair 9/15: 9893_23M57.JPG + 9893_35M50.JPG
#     ✓ Success: Age1=50.8, Age2=57.1
#   Pair 10/15: 9893_26M57.JPG + 9893_30M58.JPG
#     ✓ Success: Age1=52.1, Age2=49.8
#   Pair 11/15: 9893_26M57.JPG + 9893_31M50.JPG
#     ✓ Success: Age1=52.1, Age2=46.2
#   Pair 12/15: 9893_26M57.JPG + 9893_35M50.JPG
#     ✓ Success: Age1=52.1, Age2=57.1
#   Pair 13/15: 9893_30M58.JPG + 9893_31M50.JPG
#     ✓ Success: Age1=49.8, Age2=46.2
#   Pair 14/15: 9893_30M58.JPG + 9893_35M50.JPG
#     ✓ Success: Age1=49.8, Age2=57.1
#   Pair 15/15: 9893_31M50.JPG + 9893_35M50.JPG
#     ✓ Success: Age1=46.2, Age2=57.1
#
# ============================================================
# Processing complete!
# Total pairs found: 5892
# Successfully processed: 5892
# Failed: 0
# Results saved to: morph_preprocessing_results.csv
# ============================================================

# %% [markdown]
# # Negative Labels data collection

# %% [markdown]
# # UTKFace data collection

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jangedoo/utkface-new")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'utkface-new' dataset.
# Path to dataset files: /kaggle/input/utkface-new

# %%
import shutil
import os

# Source directory (downloaded by kagglehub)
src = "/kaggle/input/utkface-new"

# Target directory where you want to copy the dataset
dst = "/content/UTKface"

# Create destination folder if not exists
os.makedirs(dst, exist_ok=True)

# Copy entire directory tree
shutil.copytree(src, dst, dirs_exist_ok=True)

print("Dataset copied successfully to:", dst)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2367764404.py in <cell line: 0>()
#      12
#      13 # Copy entire directory tree
# ---> 14 shutil.copytree(src, dst, dirs_exist_ok=True)
#      15
#      16 print("Dataset copied successfully to:", dst)
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598     with os.scandir(src) as itr:
#     599         entries = list(itr)
# --> 600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                      ignore=ignore, copy_function=copy_function,
#     602                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.12/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     534                         copy_function(srcobj, dstname)
#     535             elif srcentry.is_dir():
# --> 536                 copytree(srcobj, dstname, symlinks, ignore, copy_function,
#     537                          ignore_dangling_symlinks, dirs_exist_ok)
#     538             else:
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598     with os.scandir(src) as itr:
#     599         entries = list(itr)
# --> 600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                      ignore=ignore, copy_function=copy_function,
#     602                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.12/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     507         srcobj = srcentry if use_srcentry else srcname
#     508         try:
# --> 509             is_symlink = srcentry.is_symlink()
#     510             if is_symlink and os.name == 'nt':
#     511                 # Special check for directory junctions, which appear as
#
# KeyboardInterrupt:

# %%
import gdown
import zipfile
import os

# Google Drive file ID and output paths
file_id = "1Fndzbip2YzCYS5Efk1f9zFNjGVZKa2Oe"
output_zip = "utkface.zip"
output_dir = "utkface_final"

# Download the file
gdown.download(f"https://drive.google.com/uc?id={file_id}", output_zip, quiet=False)

# Create directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Unzip the downloaded file
with zipfile.ZipFile(output_zip, 'r') as zip_ref:
    zip_ref.extractall(output_dir)

print(f"Dataset extracted to '{output_dir}'")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Fndzbip2YzCYS5Efk1f9zFNjGVZKa2Oe
# From (redirected): https://drive.google.com/uc?id=1Fndzbip2YzCYS5Efk1f9zFNjGVZKa2Oe&confirm=t&uuid=3b121367-71c3-48af-b1a0-559732b6dbe5
# To: /content/utkface.zip
# 100%|██████████| 347M/347M [00:04<00:00, 74.0MB/s]
# Dataset extracted to 'utkface_final'

# %%
import os

# Directory containing images
img_dir = "/content/utkface_final/utkface_aligned_cropped/UTKFace"

# Count all .jpg files
num_jpg_files = len([f for f in os.listdir(img_dir) if f.lower().endswith(".jpg")])

print(f"Number of .jpg files: {num_jpg_files}")
# Out:
# Number of .jpg files: 23708

# %%
import os
import csv
import random
from pathlib import Path
from PIL import Image
import numpy as np
import cv2
import torch
import tensorflow as tf
from facenet_pytorch import MTCNN, InceptionResnetV1
import gdown

# -----------------------------
# GPU setup
# -----------------------------
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✓ GPU memory growth enabled for {len(gpus)} GPU(s)")
    except RuntimeError as e:
        print(f"GPU configuration error: {e}")
else:
    print("Running on CPU")

# -----------------------------
# 1. Load Models
# -----------------------------
print("Loading models...")
output_path = "resnet50_age_model.keras"
if not os.path.exists(output_path):
    print("Downloading age model...")
    file_id = "1xyGYBYRQwjBpPreZmvv_enQ3Z92wHNSx"
    download_url = f"https://drive.google.com/uc?id={file_id}"
    gdown.download(download_url, output_path, quiet=False)
else:
    print("Age model already exists, skipping download...")

age_model = tf.keras.models.load_model(output_path)
mtcnn = MTCNN()
facenet = InceptionResnetV1(pretrained='vggface2').eval()
print("✓ All models loaded!")

# -----------------------------
# 2. Helper functions
# -----------------------------
def align_face(img_cv, landmark, output_size=(224, 224)):
    left_eye, right_eye, nose = landmark[0], landmark[1], landmark[2]
    eyes_center = ((left_eye[0] + right_eye[0]) / 2,
                   (left_eye[1] + right_eye[1]) / 2)
    dy, dx = right_eye[1] - left_eye[1], right_eye[0] - left_eye[0]
    angle = np.degrees(np.arctan2(dy, dx))
    desired_eye_distance = output_size[0] * 0.35
    dist = np.sqrt(dx**2 + dy**2)
    scale = desired_eye_distance / dist
    M = cv2.getRotationMatrix2D(eyes_center, angle, scale)
    M[0, 2] += (output_size[0] * 0.5 - eyes_center[0])
    M[1, 2] += (output_size[1] * 0.4 - eyes_center[1])
    aligned_face = cv2.warpAffine(img_cv, M, output_size, flags=cv2.INTER_CUBIC)
    return aligned_face

def preprocess_for_age(face_img):
    from tensorflow.keras.applications.resnet50 import preprocess_input
    x = cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return x

def preprocess_for_facenet(face_img):
    face_resized = cv2.resize(face_img, (160, 160))
    face_rgb = cv2.cvtColor(face_resized, cv2.COLOR_BGR2RGB)
    face_normalized = (face_rgb - 127.5) / 128.0
    face_tensor = torch.FloatTensor(face_normalized).permute(2, 0, 1).unsqueeze(0)
    return face_tensor

def process_image(img_path):
    try:
        img = Image.open(img_path).convert('RGB')
        img_cv = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
        boxes, probs, landmarks = mtcnn.detect(img, landmarks=True)
        if boxes is None or len(boxes) == 0:
            print(f"  ⚠ No face detected in {img_path}")
            return None, None
        aligned_face = align_face(img_cv, landmarks[0], output_size=(224, 224))
        age_input = preprocess_for_age(aligned_face)
        age = age_model.predict(age_input, verbose=0)[0][0]
        face_tensor = preprocess_for_facenet(aligned_face)
        with torch.no_grad():
            embedding = facenet(face_tensor).numpy().flatten()
        return float(age), embedding.tolist()
    except Exception as e:
        print(f"  ✗ Error processing {img_path}: {str(e)}")
        return None, None

# -----------------------------
# 3. UTKFace dataset processing (memory-efficient)
# -----------------------------
def process_utkface(dataset_root, output_csv, num_pairs=8111):
    dataset_path = Path(dataset_root)
    all_images = sorted([f for f in dataset_path.iterdir()
                         if f.suffix.lower() in ['.jpg', '.jpeg', '.png']])
    print(f"Found {len(all_images)} images in UTKFace folder")

    if len(all_images) < 2:
        print("Not enough images to form pairs!")
        return

    with open(output_csv, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['image_path1', 'image_path2', 'age1', 'age2', 'embedding1', 'embedding2'])
        total_pairs = 0
        successful_pairs = 0
        tried_pairs = set()  # to avoid duplicate pairs

        while total_pairs < num_pairs:
            img_file1, img_file2 = random.sample(all_images, 2)
            pair_key = tuple(sorted([str(img_file1), str(img_file2)]))
            if pair_key in tried_pairs:
                continue
            tried_pairs.add(pair_key)

            total_pairs += 1
            print(f"Processing pair {total_pairs}/{num_pairs}: {img_file1.name} + {img_file2.name}")
            age1, embedding1 = process_image(str(img_file1))
            age2, embedding2 = process_image(str(img_file2))
            if age1 is not None and age2 is not None:
                writer.writerow([str(img_file1), str(img_file2), age1, age2, embedding1, embedding2])
                successful_pairs += 1
                print(f"  ✓ Success: Age1={age1:.1f}, Age2={age2:.1f}")
            else:
                print(f"  ✗ Failed to process pair")

    print(f"\nProcessing complete!")
    print(f"Total pairs attempted: {total_pairs}")
    print(f"Successfully processed: {successful_pairs}")
    print(f"Failed: {total_pairs - successful_pairs}")
    print(f"Results saved to: {output_csv}")

# -----------------------------
# 4. Main execution
# -----------------------------
if __name__ == "__main__":
    dataset_root = "/content/utkface_final/utkface_aligned_cropped/UTKFace"
    output_csv = "utkface_preprocessing_results.csv"
    process_utkface(dataset_root, output_csv, num_pairs=8111)
# Out:
# Streaming output truncated to the last 5000 lines.
#   ✓ Success: Age1=30.1, Age2=32.6
# Processing pair 5624/8111: 50_0_1_20170113152855753.jpg.chip.jpg + 2_1_1_20161219155833405.jpg.chip.jpg
#   ✓ Success: Age1=35.1, Age2=1.8
# Processing pair 5625/8111: 27_1_1_20170112234022671.jpg.chip.jpg + 31_0_1_20170116024000066.jpg.chip.jpg
# Processing pair 8109/8111: 58_0_0_20170120224650587.jpg.chip.jpg + 67_0_0_20170120224536320.jpg.chip.jpg
#   ✓ Success: Age1=50.5, Age2=51.3
# Processing pair 8110/8111: 55_1_0_20170110160643422.jpg.chip.jpg + 9_0_0_20170110220236260.jpg.chip.jpg
#   ✓ Success: Age1=50.3, Age2=11.0
# Processing pair 8111/8111: 29_0_0_20170117180900108.jpg.chip.jpg + 75_0_1_20170113135403273.jpg.chip.jpg
#   ✓ Success: Age1=31.4, Age2=48.7
#
# Processing complete!
# Total pairs attempted: 8111
# Successfully processed: 8066
# Failed: 45
# Results saved to: utkface_preprocessing_results.csv

# %% [markdown]
# # Merge Positive pairs csv files

# %%
import pandas as pd

# Load both CSV files
fgnet_df = pd.read_csv("/content/fgnet_preprocessing_results.csv")
morph_df = pd.read_csv("/content/morph_preprocessing_results.csv")

# Merge them vertically (append rows)
merged_df = pd.concat([fgnet_df, morph_df], ignore_index=True)

# Print merged column names
print("Merged Columns:")
print(merged_df.columns.tolist())
# Out:
# Merged Columns:
# ['image_path1', 'image_path2', 'age1', 'age2', 'embedding1', 'embedding2']
# /tmp/ipython-input-4043677528.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged_df = pd.concat([fgnet_df, morph_df], ignore_index=True)

# %% [markdown]
# # Add person id in fgnet_csv

# %% [markdown]
# # Add person_id to morph csv

# %%
import pandas as pd

df = pd.read_csv('/content/morph_preprocessing_results.csv')

print(df.head())
# Out:
#                                          image_path1  \
# 0  /content/MLP_dataset/Positive_Morph/0007_16-44...
# 1  /content/MLP_dataset/Positive_Morph/0007_16-44...
# 2  /content/MLP_dataset/Positive_Morph/0007_16-44...
# 3  /content/MLP_dataset/Positive_Morph/00423_42-5...
# 4  /content/MLP_dataset/Positive_Morph/00423_42-5...
#
#                                          image_path2       age1       age2  \
# 0  /content/MLP_dataset/Positive_Morph/0007_16-44...  18.461182  22.550301
# 1  /content/MLP_dataset/Positive_Morph/0007_16-44...  18.461182  23.926910
# 2  /content/MLP_dataset/Positive_Morph/0007_16-44...  22.550301  23.926910
# 3  /content/MLP_dataset/Positive_Morph/00423_42-5...  29.294632  22.782116
# 4  /content/MLP_dataset/Positive_Morph/00423_42-5...  29.294632  24.953445
#
#                                           embedding1  \
# 0  [0.06365031003952026, -0.023031221702694893, 0...
# 1  [0.06365031003952026, -0.023031221702694893, 0...
# 2  [0.06384401023387909, -0.03716233745217323, 0....
# 3  [0.049127619713544846, 0.0474761463701725, 0.0...
# 4  [0.049127619713544846, 0.0474761463701725, 0.0...
#
#                                           embedding2
# 0  [0.06384401023387909, -0.03716233745217323, 0....
# 1  [0.0794190764427185, 0.017559714615345, 0.0619...
# 2  [0.0794190764427185, 0.017559714615345, 0.0619...
# 3  [0.055716048926115036, 0.014801123179495335, 0...
# 4  [0.043194856494665146, 0.03711186721920967, 0....

# %%
import pandas as pd
import os

# Load original CSV
df = pd.read_csv('/content/morph_preprocessing_results.csv')

# Extract the folder name (person folder)
def extract_folder(path):
    return os.path.basename(os.path.dirname(path))

df['folder'] = df['image_path1'].apply(extract_folder)

# Create numeric IDs for each unique folder
unique_folders = df['folder'].unique()
folder_to_id = {folder: idx+1 for idx, folder in enumerate(unique_folders)}

# Map folder → numeric ID
df['person_id'] = df['folder'].map(folder_to_id)

# Remove the temporary folder column
df = df.drop(columns=['folder'])

# Save to new CSV
output_path = '/content/morph_with_id.csv'
df.to_csv(output_path, index=False)

print("Saved new CSV:", output_path)
print(df.head(20))
# Out:
# Saved new CSV: /content/morph_with_id.csv
#                                           image_path1  \
# 0   /content/MLP_dataset/Positive_Morph/0007_16-44...
# 1   /content/MLP_dataset/Positive_Morph/0007_16-44...
# 2   /content/MLP_dataset/Positive_Morph/0007_16-44...
# 3   /content/MLP_dataset/Positive_Morph/00423_42-5...
# 4   /content/MLP_dataset/Positive_Morph/00423_42-5...
# 5   /content/MLP_dataset/Positive_Morph/00423_42-5...
# 6   /content/MLP_dataset/Positive_Morph/01083_25-3...
# 7   /content/MLP_dataset/Positive_Morph/01083_25-3...
# 8   /content/MLP_dataset/Positive_Morph/01083_25-3...
# 9   /content/MLP_dataset/Positive_Morph/01083_25-3...
# 10  /content/MLP_dataset/Positive_Morph/01083_25-3...
# 11  /content/MLP_dataset/Positive_Morph/01083_25-3...
# 12  /content/MLP_dataset/Positive_Morph/01239_27-4...
# 13  /content/MLP_dataset/Positive_Morph/0142_19-41...
# 14  /content/MLP_dataset/Positive_Morph/0142_19-41...
# 15  /content/MLP_dataset/Positive_Morph/0142_19-41...
# 16  /content/MLP_dataset/Positive_Morph/0142_19-41...
# 17  /content/MLP_dataset/Positive_Morph/0142_19-41...
# 18  /content/MLP_dataset/Positive_Morph/0142_19-41...
# 19  /content/MLP_dataset/Positive_Morph/0142_19-41...
#
#                                           image_path2       age1       age2  \
# 0   /content/MLP_dataset/Positive_Morph/0007_16-44...  18.461182  22.550301
# 1   /content/MLP_dataset/Positive_Morph/0007_16-44...  18.461182  23.926910
# 2   /content/MLP_dataset/Positive_Morph/0007_16-44...  22.550301  23.926910
# 3   /content/MLP_dataset/Positive_Morph/00423_42-5...  29.294632  22.782116
# 4   /content/MLP_dataset/Positive_Morph/00423_42-5...  29.294632  24.953445
# 5   /content/MLP_dataset/Positive_Morph/00423_42-5...  22.782116  24.953445
# 6   /content/MLP_dataset/Positive_Morph/01083_25-3...  20.750870  24.561966
# 7   /content/MLP_dataset/Positive_Morph/01083_25-3...  20.750870  18.827911
# 8   /content/MLP_dataset/Positive_Morph/01083_25-3...  20.750870  36.622700
# 9   /content/MLP_dataset/Positive_Morph/01083_25-3...  24.561966  18.827911
# 10  /content/MLP_dataset/Positive_Morph/01083_25-3...  24.561966  36.622700
# 11  /content/MLP_dataset/Positive_Morph/01083_25-3...  18.827911  36.622700
# 12  /content/MLP_dataset/Positive_Morph/01239_27-4...  49.542423  27.039398
# 13  /content/MLP_dataset/Positive_Morph/0142_19-41...  29.508320  25.038563
# 14  /content/MLP_dataset/Positive_Morph/0142_19-41...  29.508320  23.674328
# 15  /content/MLP_dataset/Positive_Morph/0142_19-41...  29.508320  29.315208
# 16  /content/MLP_dataset/Positive_Morph/0142_19-41...  29.508320  24.625454
# 17  /content/MLP_dataset/Positive_Morph/0142_19-41...  29.508320  25.552147
# 18  /content/MLP_dataset/Positive_Morph/0142_19-41...  25.038563  23.674328
# 19  /content/MLP_dataset/Positive_Morph/0142_19-41...  25.038563  29.315208
#
#                                            embedding1  \
# 0   [0.06365031003952026, -0.023031221702694893, 0...
# 1   [0.06365031003952026, -0.023031221702694893, 0...
# 2   [0.06384401023387909, -0.03716233745217323, 0....
# 3   [0.049127619713544846, 0.0474761463701725, 0.0...
# 4   [0.049127619713544846, 0.0474761463701725, 0.0...
# 5   [0.055716048926115036, 0.014801123179495335, 0...
# 6   [0.0011406326666474342, 0.05684180185198784, 0...
# 7   [0.0011406326666474342, 0.05684180185198784, 0...
# 8   [0.0011406326666474342, 0.05684180185198784, 0...
# 9   [-0.021664995700120926, 0.02306981384754181, 0...
# 10  [-0.021664995700120926, 0.02306981384754181, 0...
# 11  [0.0006334870704449713, 0.021985940635204315, ...
# 12  [0.08057626336812973, -0.035883765667676926, -...
# 13  [0.042462706565856934, 0.013234260492026806, 0...
# 14  [0.042462706565856934, 0.013234260492026806, 0...
# 15  [0.042462706565856934, 0.013234260492026806, 0...
# 16  [0.042462706565856934, 0.013234260492026806, 0...
# 17  [0.042462706565856934, 0.013234260492026806, 0...
# 18  [0.01752742938697338, -0.03755446895956993, 0....
# 19  [0.01752742938697338, -0.03755446895956993, 0....
#
#                                            embedding2  person_id
# 0   [0.06384401023387909, -0.03716233745217323, 0....          1
# 1   [0.0794190764427185, 0.017559714615345, 0.0619...          1
# 2   [0.0794190764427185, 0.017559714615345, 0.0619...          1
# 3   [0.055716048926115036, 0.014801123179495335, 0...          2
# 4   [0.043194856494665146, 0.03711186721920967, 0....          2
# 5   [0.043194856494665146, 0.03711186721920967, 0....          2
# 6   [-0.021664995700120926, 0.02306981384754181, 0...          3
# 7   [0.0006334870704449713, 0.021985940635204315, ...          3
# 8   [0.026137322187423706, 0.04060067608952522, 0....          3
# 9   [0.0006334870704449713, 0.021985940635204315, ...          3
# 10  [0.026137322187423706, 0.04060067608952522, 0....          3
# 11  [0.026137322187423706, 0.04060067608952522, 0....          3
# 12  [-0.008373431861400604, -0.027534933760762215,...          4
# 13  [0.01752742938697338, -0.03755446895956993, 0....          5
# 14  [-0.0038214584346860647, -0.07492691278457642,...          5
# 15  [0.03179369866847992, -0.019678227603435516, -...          5
# 16  [0.030680250376462936, -0.060404013842344284, ...          5
# 17  [0.027805624529719353, -0.006833902560174465, ...          5
# 18  [-0.0038214584346860647, -0.07492691278457642,...          5
# 19  [0.03179369866847992, -0.019678227603435516, -...          5

# %%
print("Last person_id:", df['person_id'].max())
# Out:
# Last person_id: 289

# %%
print(df.tail(20))   # shows last 20 rows
# Out:
#                                             image_path1  \
# 5872  /content/MLP_dataset/Positive_Morph/95104_33-4...
# 5873  /content/MLP_dataset/Positive_Morph/97729_20-3...
# 5874  /content/MLP_dataset/Positive_Morph/97729_20-3...
# 5875  /content/MLP_dataset/Positive_Morph/97729_20-3...
# 5876  /content/MLP_dataset/Positive_Morph/98025_22-2...
# 5877  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5878  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5879  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5880  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5881  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5882  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5883  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5884  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5885  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5886  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5887  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5888  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5889  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5890  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 5891  /content/MLP_dataset/Positive_Morph/9893_50-58...
#
#                                             image_path2       age1       age2  \
# 5872  /content/MLP_dataset/Positive_Morph/95104_33-4...  20.767298  42.521076
# 5873  /content/MLP_dataset/Positive_Morph/97729_20-3...  30.734829  25.620010
# 5874  /content/MLP_dataset/Positive_Morph/97729_20-3...  30.734829  27.196728
# 5875  /content/MLP_dataset/Positive_Morph/97729_20-3...  25.620010  27.196728
# 5876  /content/MLP_dataset/Positive_Morph/98025_22-2...  21.650150  30.392223
# 5877  /content/MLP_dataset/Positive_Morph/9893_50-58...  53.230427  50.811939
# 5878  /content/MLP_dataset/Positive_Morph/9893_50-58...  53.230427  52.085430
# 5879  /content/MLP_dataset/Positive_Morph/9893_50-58...  53.230427  49.811337
# 5880  /content/MLP_dataset/Positive_Morph/9893_50-58...  53.230427  46.217159
# 5881  /content/MLP_dataset/Positive_Morph/9893_50-58...  53.230427  57.117596
# 5882  /content/MLP_dataset/Positive_Morph/9893_50-58...  50.811939  52.085430
# 5883  /content/MLP_dataset/Positive_Morph/9893_50-58...  50.811939  49.811337
# 5884  /content/MLP_dataset/Positive_Morph/9893_50-58...  50.811939  46.217159
# 5885  /content/MLP_dataset/Positive_Morph/9893_50-58...  50.811939  57.117596
# 5886  /content/MLP_dataset/Positive_Morph/9893_50-58...  52.085430  49.811337
# 5887  /content/MLP_dataset/Positive_Morph/9893_50-58...  52.085430  46.217159
# 5888  /content/MLP_dataset/Positive_Morph/9893_50-58...  52.085430  57.117596
# 5889  /content/MLP_dataset/Positive_Morph/9893_50-58...  49.811337  46.217159
# 5890  /content/MLP_dataset/Positive_Morph/9893_50-58...  49.811337  57.117596
# 5891  /content/MLP_dataset/Positive_Morph/9893_50-58...  46.217159  57.117596
#
#                                              embedding1  \
# 5872  [0.007829968817532063, 0.011169063858687878, -...
# 5873  [0.017187612131237984, -0.044551730155944824, ...
# 5874  [0.017187612131237984, -0.044551730155944824, ...
# 5875  [0.07180990278720856, -0.08746062964200974, 0....
# 5876  [0.08726723492145538, 0.030490564182400703, 0....
# 5877  [0.05375527963042259, -0.11296854168176651, 0....
# 5878  [0.05375527963042259, -0.11296854168176651, 0....
# 5879  [0.05375527963042259, -0.11296854168176651, 0....
# 5880  [0.05375527963042259, -0.11296854168176651, 0....
# 5881  [0.05375527963042259, -0.11296854168176651, 0....
# 5882  [0.05404316633939743, -0.0954873338341713, -0....
# 5883  [0.05404316633939743, -0.0954873338341713, -0....
# 5884  [0.05404316633939743, -0.0954873338341713, -0....
# 5885  [0.05404316633939743, -0.0954873338341713, -0....
# 5886  [0.07272685319185257, -0.11134401708841324, 0....
# 5887  [0.07272685319185257, -0.11134401708841324, 0....
# 5888  [0.07272685319185257, -0.11134401708841324, 0....
# 5889  [0.08547382056713104, -0.07386672496795654, 0....
# 5890  [0.08547382056713104, -0.07386672496795654, 0....
# 5891  [0.05687617138028145, -0.10980159044265747, 0....
#
#                                              embedding2  person_id
# 5872  [0.04304451495409012, -0.020515797659754753, -...        286
# 5873  [0.07180990278720856, -0.08746062964200974, 0....        287
# 5874  [0.00999752338975668, -0.03144454210996628, -0...        287
# 5875  [0.00999752338975668, -0.03144454210996628, -0...        287
# 5876  [0.057634640485048294, 0.012240080162882805, -...        288
# 5877  [0.05404316633939743, -0.0954873338341713, -0....        289
# 5878  [0.07272685319185257, -0.11134401708841324, 0....        289
# 5879  [0.08547382056713104, -0.07386672496795654, 0....        289
# 5880  [0.05687617138028145, -0.10980159044265747, 0....        289
# 5881  [0.06789958477020264, -0.07003810256719589, 0....        289
# 5882  [0.07272685319185257, -0.11134401708841324, 0....        289
# 5883  [0.08547382056713104, -0.07386672496795654, 0....        289
# 5884  [0.05687617138028145, -0.10980159044265747, 0....        289
# 5885  [0.06789958477020264, -0.07003810256719589, 0....        289
# 5886  [0.08547382056713104, -0.07386672496795654, 0....        289
# 5887  [0.05687617138028145, -0.10980159044265747, 0....        289
# 5888  [0.06789958477020264, -0.07003810256719589, 0....        289
# 5889  [0.05687617138028145, -0.10980159044265747, 0....        289
# 5890  [0.06789958477020264, -0.07003810256719589, 0....        289
# 5891  [0.06789958477020264, -0.07003810256719589, 0....        289

# %% [markdown]
# # FGNET ADDING PERSON_ID

# %%
import pandas as pd

df2 = pd.read_excel('/content/fgnet_preprocessing_results_v2.xlsx')

print(df2.head())
# Out:
#                                          image_path1  \
# 0  MLP_dataset/Positive_FGNET/person001/person001...
# 1  MLP_dataset/Positive_FGNET/person001/person001...
# 2  MLP_dataset/Positive_FGNET/person001/person001...
# 3  MLP_dataset/Positive_FGNET/person001/person001...
# 4  MLP_dataset/Positive_FGNET/person001/person001...
#
#                                          image_path2      age1       age2  \
# 0  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  27.186808
# 1  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  20.907551
# 2  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  31.123674
# 3  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  23.976097
# 4  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  34.156021
#
#                                           embedding1  \
# 0  [-0.021442148834466934, 0.04521297663450241, 0...
# 1  [-0.021442148834466934, 0.04521297663450241, 0...
# 2  [-0.021442148834466934, 0.04521297663450241, 0...
# 3  [-0.021442148834466934, 0.04521297663450241, 0...
# 4  [-0.021442148834466934, 0.04521297663450241, 0...
#
#                                           embedding2
# 0  [0.012546641752123833, 0.05395905300974846, 0....
# 1  [-0.02376442216336727, 0.005307325161993504, -...
# 2  [-0.021765317767858505, 0.016306184232234955, ...
# 3  [-0.07456657290458679, 0.06233188882470131, 0....
# 4  [-0.06039056181907654, 0.03492215275764465, -0...

# %%
import pandas as pd
import os

# Load Excel file
df2 = pd.read_excel('/content/fgnet_preprocessing_results_v2.xlsx')

# Function to extract the subfolder after Positive_FGNET
def extract_person_folder(path):
    parts = path.split(os.sep)  # split by path separator
    # find the index of 'Positive_FGNET' and take the next folder
    if 'Positive_FGNET' in parts:
        idx = parts.index('Positive_FGNET')
        return parts[idx + 1]
    else:
        return 'unknown'

# Apply to image_path1
df2['folder'] = df2['image_path1'].apply(extract_person_folder)

# Get unique folders
unique_folders = df2['folder'].unique()

# Map folders to numeric IDs starting from 290
folder_to_id = {folder: idx + 290 for idx, folder in enumerate(unique_folders)}
df2['person_id'] = df2['folder'].map(folder_to_id)

# Drop temporary folder column
df2 = df2.drop(columns=['folder'])

# Save updated Excel file
output_path = '/content/fgnet2_with_id.xlsx'
df2.to_excel(output_path, index=False)

print("Saved new Excel file with person_id:", output_path)
print(df2.head(20))   # show top 20 rows
print("Last person_id:", df2['person_id'].max())
# Out:
# Saved new Excel file with person_id: /content/fgnet2_with_id.xlsx
#                                           image_path1  \
# 0   MLP_dataset/Positive_FGNET/person001/person001...
# 1   MLP_dataset/Positive_FGNET/person001/person001...
# 2   MLP_dataset/Positive_FGNET/person001/person001...
# 3   MLP_dataset/Positive_FGNET/person001/person001...
# 4   MLP_dataset/Positive_FGNET/person001/person001...
# 5   MLP_dataset/Positive_FGNET/person001/person001...
# 6   MLP_dataset/Positive_FGNET/person001/person001...
# 7   MLP_dataset/Positive_FGNET/person001/person001...
# 8   MLP_dataset/Positive_FGNET/person001/person001...
# 9   MLP_dataset/Positive_FGNET/person001/person001...
# 10  MLP_dataset/Positive_FGNET/person001/person001...
# 11  MLP_dataset/Positive_FGNET/person001/person001...
# 12  MLP_dataset/Positive_FGNET/person001/person001...
# 13  MLP_dataset/Positive_FGNET/person001/person001...
# 14  MLP_dataset/Positive_FGNET/person001/person001...
# 15  MLP_dataset/Positive_FGNET/person001/person001...
# 16  MLP_dataset/Positive_FGNET/person001/person001...
# 17  MLP_dataset/Positive_FGNET/person001/person001...
# 18  MLP_dataset/Positive_FGNET/person001/person001...
# 19  MLP_dataset/Positive_FGNET/person001/person001...
#
#                                           image_path2       age1       age2  \
# 0   MLP_dataset/Positive_FGNET/person001/person001...   4.660048  27.186808
# 1   MLP_dataset/Positive_FGNET/person001/person001...   4.660048  20.907551
# 2   MLP_dataset/Positive_FGNET/person001/person001...   4.660048  31.123674
# 3   MLP_dataset/Positive_FGNET/person001/person001...   4.660048  23.976097
# 4   MLP_dataset/Positive_FGNET/person001/person001...   4.660048  34.156021
# 5   MLP_dataset/Positive_FGNET/person001/person001...   4.660048  19.371302
# 6   MLP_dataset/Positive_FGNET/person001/person001...   4.660048  29.213449
# 7   MLP_dataset/Positive_FGNET/person001/person001...   4.660048  33.349995
# 8   MLP_dataset/Positive_FGNET/person001/person001...   4.660048  39.246082
# 9   MLP_dataset/Positive_FGNET/person001/person001...  11.891588  20.907551
# 10  MLP_dataset/Positive_FGNET/person001/person001...  11.891588  31.123674
# 11  MLP_dataset/Positive_FGNET/person001/person001...  11.891588  23.976097
# 12  MLP_dataset/Positive_FGNET/person001/person001...  11.891588  34.156021
# 13  MLP_dataset/Positive_FGNET/person001/person001...  11.891588  19.371302
# 14  MLP_dataset/Positive_FGNET/person001/person001...  11.891588  29.213449
# 15  MLP_dataset/Positive_FGNET/person001/person001...  11.891588  33.349995
# 16  MLP_dataset/Positive_FGNET/person001/person001...  11.891588  39.246082
# 17  MLP_dataset/Positive_FGNET/person001/person001...  13.361890  23.976097
# 18  MLP_dataset/Positive_FGNET/person001/person001...  13.361890  34.156021
# 19  MLP_dataset/Positive_FGNET/person001/person001...  13.361890  19.371302
#
#                                            embedding1  \
# 0   [-0.021442148834466934, 0.04521297663450241, 0...
# 1   [-0.021442148834466934, 0.04521297663450241, 0...
# 2   [-0.021442148834466934, 0.04521297663450241, 0...
# 3   [-0.021442148834466934, 0.04521297663450241, 0...
# 4   [-0.021442148834466934, 0.04521297663450241, 0...
# 5   [-0.021442148834466934, 0.04521297663450241, 0...
# 6   [-0.021442148834466934, 0.04521297663450241, 0...
# 7   [-0.021442148834466934, 0.04521297663450241, 0...
# 8   [-0.021442148834466934, 0.04521297663450241, 0...
# 9   [-0.011465521529316902, 0.12174055725336075, 0...
# 10  [-0.011465521529316902, 0.12174055725336075, 0...
# 11  [-0.011465521529316902, 0.12174055725336075, 0...
# 12  [-0.011465521529316902, 0.12174055725336075, 0...
# 13  [-0.011465521529316902, 0.12174055725336075, 0...
# 14  [-0.011465521529316902, 0.12174055725336075, 0...
# 15  [-0.011465521529316902, 0.12174055725336075, 0...
# 16  [-0.011465521529316902, 0.12174055725336075, 0...
# 17  [-0.028731657192111015, 0.1024153009057045, 0....
# 18  [-0.028731657192111015, 0.1024153009057045, 0....
# 19  [-0.028731657192111015, 0.1024153009057045, 0....
#
#                                            embedding2  person_id
# 0   [0.012546641752123833, 0.05395905300974846, 0....        290
# 1   [-0.02376442216336727, 0.005307325161993504, -...        290
# 2   [-0.021765317767858505, 0.016306184232234955, ...        290
# 3   [-0.07456657290458679, 0.06233188882470131, 0....        290
# 4   [-0.06039056181907654, 0.03492215275764465, -0...        290
# 5   [-0.05342762917280197, -0.004006947856396437, ...        290
# 6   [-0.04568270221352577, 0.000494216219522059, -...        290
# 7   [-0.07034648954868317, -0.012670819647610188, ...        290
# 8   [-0.05529921501874924, 0.005811037961393595, -...        290
# 9   [-0.02376442216336727, 0.005307325161993504, -...        290
# 10  [-0.021765317767858505, 0.016306184232234955, ...        290
# 11  [-0.07456657290458679, 0.06233188882470131, 0....        290
# 12  [-0.06039056181907654, 0.03492215275764465, -0...        290
# 13  [-0.05342762917280197, -0.004006947856396437, ...        290
# 14  [-0.04568270221352577, 0.000494216219522059, -...        290
# 15  [-0.07034648954868317, -0.012670819647610188, ...        290
# 16  [-0.05529921501874924, 0.005811037961393595, -...        290
# 17  [-0.07456657290458679, 0.06233188882470131, 0....        290
# 18  [-0.06039056181907654, 0.03492215275764465, -0...        290
# 19  [-0.05342762917280197, -0.004006947856396437, ...        290
# Last person_id: 370

# %% [markdown]
# # Merge both

# %%
import pandas as pd

# Load the files
fgnet_df = pd.read_excel('/content/fgnet2_with_id.xlsx')
morph_df = pd.read_csv('/content/morph_with_id.csv')

# Merge the datasets (concatenate rows)
merged_df = pd.concat([morph_df,fgnet_df ], ignore_index=True)

# Print the columns of the merged dataframe
print("Columns in merged dataframe:", merged_df.columns.tolist())

# Optional: show top rows
print(merged_df.head())
print(merged_df.tail())
# Out:
# Columns in merged dataframe: ['image_path1', 'image_path2', 'age1', 'age2', 'embedding1', 'embedding2', 'person_id']
#                                          image_path1  \
# 0  /content/MLP_dataset/Positive_Morph/0007_16-44...
# 1  /content/MLP_dataset/Positive_Morph/0007_16-44...
# 2  /content/MLP_dataset/Positive_Morph/0007_16-44...
# 3  /content/MLP_dataset/Positive_Morph/00423_42-5...
# 4  /content/MLP_dataset/Positive_Morph/00423_42-5...
#
#                                          image_path2       age1       age2  \
# 0  /content/MLP_dataset/Positive_Morph/0007_16-44...  18.461182  22.550301
# 1  /content/MLP_dataset/Positive_Morph/0007_16-44...  18.461182  23.926910
# 2  /content/MLP_dataset/Positive_Morph/0007_16-44...  22.550301  23.926910
# 3  /content/MLP_dataset/Positive_Morph/00423_42-5...  29.294632  22.782116
# 4  /content/MLP_dataset/Positive_Morph/00423_42-5...  29.294632  24.953445
#
#                                           embedding1  \
# 0  [0.06365031003952026, -0.023031221702694893, 0...
# 1  [0.06365031003952026, -0.023031221702694893, 0...
# 2  [0.06384401023387909, -0.03716233745217323, 0....
# 3  [0.049127619713544846, 0.0474761463701725, 0.0...
# 4  [0.049127619713544846, 0.0474761463701725, 0.0...
#
#                                           embedding2  person_id
# 0  [0.06384401023387909, -0.03716233745217323, 0....          1
# 1  [0.0794190764427185, 0.017559714615345, 0.0619...          1
# 2  [0.0794190764427185, 0.017559714615345, 0.0619...          1
# 3  [0.055716048926115036, 0.014801123179495335, 0...          2
# 4  [0.043194856494665146, 0.03711186721920967, 0....          2
#                                             image_path1  \
# 8106  MLP_dataset/Positive_FGNET/person082/person082...
# 8107  MLP_dataset/Positive_FGNET/person082/person082...
# 8108  MLP_dataset/Positive_FGNET/person082/person082...
# 8109  MLP_dataset/Positive_FGNET/person082/person082...
# 8110  MLP_dataset/Positive_FGNET/person082/person082...
#
#                                             image_path2       age1       age2  \
# 8106  MLP_dataset/Positive_FGNET/person082/person082...   9.632227  18.203125
# 8107  MLP_dataset/Positive_FGNET/person082/person082...  17.635006  20.767109
# 8108  MLP_dataset/Positive_FGNET/person082/person082...  17.635006  18.203125
# 8109  MLP_dataset/Positive_FGNET/person082/person082...  23.057657  18.203125
# 8110  MLP_dataset/Positive_FGNET/person082/person082...  25.597195  18.203125
#
#                                              embedding1  \
# 8106  [0.04122454673051834, 0.043139003217220306, -0...
# 8107  [0.032224141061306, 0.027210619300603867, 0.04...
# 8108  [0.032224141061306, 0.027210619300603867, 0.04...
# 8109  [-0.00783152598887682, 0.07158984988927841, 0....
# 8110  [0.038033001124858856, 0.02072850428521633, 0....
#
#                                              embedding2  person_id
# 8106  [-0.03141973540186882, 0.09797055274248123, 0....        370
# 8107  [-0.03795517608523369, 0.053412068635225296, 0...        370
# 8108  [-0.03141973540186882, 0.09797055274248123, 0....        370
# 8109  [-0.03141973540186882, 0.09797055274248123, 0....        370
# 8110  [-0.03141973540186882, 0.09797055274248123, 0....        370

# %% [markdown]
# # Add label =1 and age range and embedding difference

# %%
import pandas as pd
import ast
import numpy as np

# Load the files
fgnet_df = pd.read_excel('/content/fgnet2_with_id.xlsx')
morph_df = pd.read_csv('/content/morph_with_id.csv')

# Merge the datasets
merged_df = pd.concat([fgnet_df, morph_df], ignore_index=True)

# Add label column
merged_df['label'] = 1

# Compute age difference
merged_df['age_range'] = (merged_df['age1'] - merged_df['age2']).abs()

# Convert embeddings from string to list
def str_to_array(s):
    return np.array(ast.literal_eval(s))

merged_df['embedding1'] = merged_df['embedding1'].apply(str_to_array)
merged_df['embedding2'] = merged_df['embedding2'].apply(str_to_array)

# Compute L1 distance (element-wise absolute difference sum)
merged_df['embedding_diff'] = merged_df.apply(
    lambda row: np.sum(np.abs(row['embedding1'] - row['embedding2'])),
    axis=1
)

# Save to CSV
merged_df.to_csv('/content/Final_Positive.csv', index=False)

# Print top rows to verify
print(merged_df.head())
# Out:
#                                          image_path1  \
# 0  MLP_dataset/Positive_FGNET/person001/person001...
# 1  MLP_dataset/Positive_FGNET/person001/person001...
# 2  MLP_dataset/Positive_FGNET/person001/person001...
# 3  MLP_dataset/Positive_FGNET/person001/person001...
# 4  MLP_dataset/Positive_FGNET/person001/person001...
#
#                                          image_path2      age1       age2  \
# 0  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  27.186808
# 1  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  20.907551
# 2  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  31.123674
# 3  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  23.976097
# 4  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  34.156021
#
#                                           embedding1  \
# 0  [-0.021442148834466934, 0.04521297663450241, 0...
# 1  [-0.021442148834466934, 0.04521297663450241, 0...
# 2  [-0.021442148834466934, 0.04521297663450241, 0...
# 3  [-0.021442148834466934, 0.04521297663450241, 0...
# 4  [-0.021442148834466934, 0.04521297663450241, 0...
#
#                                           embedding2  person_id  label  \
# 0  [0.012546641752123833, 0.05395905300974846, 0....        290      1
# 1  [-0.02376442216336727, 0.005307325161993504, -...        290      1
# 2  [-0.021765317767858505, 0.016306184232234955, ...        290      1
# 3  [-0.07456657290458679, 0.06233188882470131, 0....        290      1
# 4  [-0.06039056181907654, 0.03492215275764465, -0...        290      1
#
#    age_range  embedding_diff
# 0  22.526760       20.119748
# 1  16.247503       20.951237
# 2  26.463626       24.996013
# 3  19.316049       21.990617
# 4  29.495973       20.399040

# %%
print(merged_df.tail())
# Out:
#                                             image_path1  \
# 8106  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 8107  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 8108  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 8109  /content/MLP_dataset/Positive_Morph/9893_50-58...
# 8110  /content/MLP_dataset/Positive_Morph/9893_50-58...
#
#                                             image_path2       age1       age2  \
# 8106  /content/MLP_dataset/Positive_Morph/9893_50-58...  52.085430  46.217159
# 8107  /content/MLP_dataset/Positive_Morph/9893_50-58...  52.085430  57.117596
# 8108  /content/MLP_dataset/Positive_Morph/9893_50-58...  49.811337  46.217159
# 8109  /content/MLP_dataset/Positive_Morph/9893_50-58...  49.811337  57.117596
# 8110  /content/MLP_dataset/Positive_Morph/9893_50-58...  46.217159  57.117596
#
#                                              embedding1  \
# 8106  [0.07272685319185257, -0.11134401708841324, 0....
# 8107  [0.07272685319185257, -0.11134401708841324, 0....
# 8108  [0.08547382056713104, -0.07386672496795654, 0....
# 8109  [0.08547382056713104, -0.07386672496795654, 0....
# 8110  [0.05687617138028145, -0.10980159044265747, 0....
#
#                                              embedding2  person_id  label  \
# 8106  [0.05687617138028145, -0.10980159044265747, 0....        289      1
# 8107  [0.06789958477020264, -0.07003810256719589, 0....        289      1
# 8108  [0.05687617138028145, -0.10980159044265747, 0....        289      1
# 8109  [0.06789958477020264, -0.07003810256719589, 0....        289      1
# 8110  [0.06789958477020264, -0.07003810256719589, 0....        289      1
#
#       age_range  embedding_diff
# 8106   5.868271       11.848493
# 8107   5.032166       13.199525
# 8108   3.594177        9.800796
# 8109   7.306259       12.278072
# 8110  10.900436       11.662380

# %%
from google.colab import drive
import shutil

# Mount Google Drive
drive.mount('/content/drive')

# Define the destination path in your Drive
destination_path = '/content/drive/MyDrive/Final_Positive.csv'

# Copy the file to Drive
shutil.copy('/content/Final_Positive.csv', destination_path)

print(f"File saved to: {destination_path}")
# Out:
# Mounted at /content/drive
# File saved to: /content/drive/MyDrive/Final_Positive.csv

# %% [markdown]
# # Prepare negative pairs csv file

# %%
import pandas as pd

# Load the CSV
utk_df = pd.read_csv('/content/utkface_preprocessing_results.csv')

# Add label column
utk_df['label'] = 0

# Add person_id column (unique for each row)
utk_df['person_id'] = range(1, len(utk_df) + 1)

# Save back to CSV (optional)
utk_df.to_csv('/content/utkface_with_id.csv', index=False)

# Print top rows to verify
print(utk_df.head())
# Out:
#                                          image_path1  \
# 0  /content/utkface_final/utkface_aligned_cropped...
# 1  /content/utkface_final/utkface_aligned_cropped...
# 2  /content/utkface_final/utkface_aligned_cropped...
# 3  /content/utkface_final/utkface_aligned_cropped...
# 4  /content/utkface_final/utkface_aligned_cropped...
#
#                                          image_path2       age1       age2  \
# 0  /content/utkface_final/utkface_aligned_cropped...  44.116760  26.153221
# 1  /content/utkface_final/utkface_aligned_cropped...  47.330673  21.295252
# 2  /content/utkface_final/utkface_aligned_cropped...  31.084494  45.400433
# 3  /content/utkface_final/utkface_aligned_cropped...  38.734959  33.677563
# 4  /content/utkface_final/utkface_aligned_cropped...  50.781651  30.622351
#
#                                           embedding1  \
# 0  [0.049472421407699585, 0.010554309003055096, 0...
# 1  [0.003280659904703498, 0.012418401427567005, 0...
# 2  [-0.044035427272319794, -0.043001189827919006,...
# 3  [0.06379140168428421, -0.04785529151558876, -0...
# 4  [0.029916109517216682, -0.039313457906246185, ...
#
#                                           embedding2  label  person_id
# 0  [-0.07858560979366302, 0.034238822758197784, 0...      0          1
# 1  [-0.04367154464125633, 0.07399284839630127, 0....      0          2
# 2  [0.04980834946036339, 0.03798415884375572, 0.0...      0          3
# 3  [0.07273823022842407, -0.024925990030169487, -...      0          4
# 4  [0.05722593516111374, 0.0029364193323999643, -...      0          5

# %%
import pandas as pd
import ast
import numpy as np
from google.colab import drive
import shutil

# --- Step 1: Load datasets ---

merged_df = pd.read_csv('/content/Final_Positive.csv')  # FGNET + Morph
utk_df = pd.read_csv('/content/utkface_preprocessing_results.csv')

# --- Step 2: Process UTKFace ---

# Add label
utk_df['label'] = 0

# Add person_id (unique per row)
utk_df['person_id'] = range(1, len(utk_df) + 1)

# Compute age difference if age1 and age2 exist
if 'age1' in utk_df.columns and 'age2' in utk_df.columns:
    utk_df['age_range'] = (utk_df['age1'] - utk_df['age2']).abs()
else:
    utk_df['age_range'] = 0  # fallback if no age columns

# Compute embedding difference if embedding1 and embedding2 exist
if 'embedding1' in utk_df.columns and 'embedding2' in utk_df.columns:
    def str_to_array(s):
        return np.array(ast.literal_eval(s))

    utk_df['embedding1'] = utk_df['embedding1'].apply(str_to_array)
    utk_df['embedding2'] = utk_df['embedding2'].apply(str_to_array)

    utk_df['embedding_diff'] = utk_df.apply(
        lambda row: np.sum(np.abs(row['embedding1'] - row['embedding2'])),
        axis=1
    )
else:
    utk_df['embedding_diff'] = 0

print(utk_df.head())
# Out:
#                                          image_path1  \
# 0  /content/utkface_final/utkface_aligned_cropped...
# 1  /content/utkface_final/utkface_aligned_cropped...
# 2  /content/utkface_final/utkface_aligned_cropped...
# 3  /content/utkface_final/utkface_aligned_cropped...
# 4  /content/utkface_final/utkface_aligned_cropped...
#
#                                          image_path2       age1       age2  \
# 0  /content/utkface_final/utkface_aligned_cropped...  44.116760  26.153221
# 1  /content/utkface_final/utkface_aligned_cropped...  47.330673  21.295252
# 2  /content/utkface_final/utkface_aligned_cropped...  31.084494  45.400433
# 3  /content/utkface_final/utkface_aligned_cropped...  38.734959  33.677563
# 4  /content/utkface_final/utkface_aligned_cropped...  50.781651  30.622351
#
#                                           embedding1  \
# 0  [0.049472421407699585, 0.010554309003055096, 0...
# 1  [0.003280659904703498, 0.012418401427567005, 0...
# 2  [-0.044035427272319794, -0.043001189827919006,...
# 3  [0.06379140168428421, -0.04785529151558876, -0...
# 4  [0.029916109517216682, -0.039313457906246185, ...
#
#                                           embedding2  label  person_id  \
# 0  [-0.07858560979366302, 0.034238822758197784, 0...      0          1
# 1  [-0.04367154464125633, 0.07399284839630127, 0....      0          2
# 2  [0.04980834946036339, 0.03798415884375572, 0.0...      0          3
# 3  [0.07273823022842407, -0.024925990030169487, -...      0          4
# 4  [0.05722593516111374, 0.0029364193323999643, -...      0          5
#
#    age_range  embedding_diff
# 0  17.963539       22.996682
# 1  26.035421       26.823485
# 2  14.315939       27.399711
# 3   5.057396       23.759129
# 4  20.159300       25.108061

# %%
# --- Step 3: Merge datasets ---
final_mlp_df = pd.concat([merged_df, utk_df], ignore_index=True)

# --- Step 4: Save locally ---
final_mlp_csv_path = '/content/final_mlp_csv.csv'
final_mlp_df.to_csv(final_mlp_csv_path, index=False)

# --- Step 5: Show head and tail ---
print("Head of final_mlp_df:")
print(final_mlp_df.head())
print("\nTail of final_mlp_df:")
print(final_mlp_df.tail())

# --- Step 6: Mount Google Drive and save there ---
drive.mount('/content/drive')

destination_path = '/content/drive/MyDrive/final_mlp_csv.csv'
shutil.copy(final_mlp_csv_path, destination_path)

print(f"\nFile saved to Google Drive at: {destination_path}")
# Out:
# Head of final_mlp_df:
#                                          image_path1  \
# 0  MLP_dataset/Positive_FGNET/person001/person001...
# 1  MLP_dataset/Positive_FGNET/person001/person001...
# 2  MLP_dataset/Positive_FGNET/person001/person001...
# 3  MLP_dataset/Positive_FGNET/person001/person001...
# 4  MLP_dataset/Positive_FGNET/person001/person001...
#
#                                          image_path2      age1       age2  \
# 0  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  27.186808
# 1  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  20.907551
# 2  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  31.123674
# 3  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  23.976097
# 4  MLP_dataset/Positive_FGNET/person001/person001...  4.660048  34.156021
#
#                                           embedding1  \
# 0  [-2.14421488e-02  4.52129766e-02  2.54299995e-...
# 1  [-2.14421488e-02  4.52129766e-02  2.54299995e-...
# 2  [-2.14421488e-02  4.52129766e-02  2.54299995e-...
# 3  [-2.14421488e-02  4.52129766e-02  2.54299995e-...
# 4  [-2.14421488e-02  4.52129766e-02  2.54299995e-...
#
#                                           embedding2  person_id  label  \
# 0  [ 1.25466418e-02  5.39590530e-02  2.54650246e-...        290      1
# 1  [-2.37644222e-02  5.30732516e-03 -3.21395770e-...        290      1
# 2  [-0.02176532  0.01630618  0.0509095   0.030927...        290      1
# 3  [-7.45665729e-02  6.23318888e-02  1.01557905e-...        290      1
# 4  [-6.03905618e-02  3.49221528e-02 -1.05816433e-...        290      1
#
#    age_range  embedding_diff
# 0  22.526760       20.119748
# 1  16.247503       20.951237
# 2  26.463626       24.996013
# 3  19.316049       21.990617
# 4  29.495973       20.399040
#
# Tail of final_mlp_df:
#                                              image_path1  \
# 16172  /content/utkface_final/utkface_aligned_cropped...
# 16173  /content/utkface_final/utkface_aligned_cropped...
# 16174  /content/utkface_final/utkface_aligned_cropped...
# 16175  /content/utkface_final/utkface_aligned_cropped...
# 16176  /content/utkface_final/utkface_aligned_cropped...
#
#                                              image_path2       age1  \
# 16172  /content/utkface_final/utkface_aligned_cropped...  42.074112
# 16173  /content/utkface_final/utkface_aligned_cropped...   2.583868
# 16174  /content/utkface_final/utkface_aligned_cropped...  50.499519
# 16175  /content/utkface_final/utkface_aligned_cropped...  50.252529
# 16176  /content/utkface_final/utkface_aligned_cropped...  31.373695
#
#             age2                                         embedding1  \
# 16172  36.256176  [0.0997062623500824, -0.0018880238058045506, -...
# 16173   1.316906  [0.10147587209939957, -0.046189941465854645, 0...
# 16174  51.263248  [0.09087681025266647, 0.006259307265281677, -0...
# 16175  10.981280  [-0.0265096016228199, 0.018889041617512703, 0....
# 16176  48.738121  [0.007851173169910908, -0.027927586808800697, ...
#
#                                               embedding2  person_id  label  \
# 16172  [-0.0185580812394619, 0.014885015785694122, -0...       8062      0
# 16173  [0.06867766380310059, 0.038034506142139435, -0...       8063      0
# 16174  [0.078960120677948, -0.020973684266209602, -0....       8064      0
# 16175  [-0.06845157593488693, 0.015926258638501167, -...       8065      0
# 16176  [0.09392125904560089, 0.03733338043093681, -0....       8066      0
#
#        age_range  embedding_diff
# 16172   5.817936       22.692702
# 16173   1.266962       14.920930
# 16174   0.763729       23.524907
# 16175  39.271249       27.341151
# 16176  17.364426       28.781976
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# File saved to Google Drive at: /content/drive/MyDrive/final_mlp_csv.csv
